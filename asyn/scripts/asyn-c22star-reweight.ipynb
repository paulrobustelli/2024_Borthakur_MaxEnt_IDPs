# %%
from reweight_functions import *
import pickle

# %% [markdown]
# SETTING THE DIRECTORIES TO THE EXPERIMENTAL, COMPUTED DATA AND MAKING DIRECTORIES FOR THE OUTPUT AND FOR SAVING THE REWEIGHTED RMSES AS DICTIONARIES IN THEIR OWN DIRECTORIES

# %%
main_path = '/Users/kaushikb/Desktop/Paper_Repo/asyn/'

outdir = os.path.join(main_path, 'c22star-TIP3P', 'reweight_trial')
datadir = os.path.join(main_path, 'c22star-TIP3P', 'Average_Data')
expdatadir = os.path.join(main_path, 'Exp_Data')
weights_dir = os.path.join(outdir, 'weights')

if not os.path.exists(outdir):
    os.makedirs(outdir)
if not os.path.exists(weights_dir):
    os.makedirs(weights_dir)

single_dir = os.path.join(weights_dir + "/single_data")
if not os.path.exists(single_dir):
    os.makedirs(single_dir)
leave_dir = os.path.join(weights_dir + "/leave_one_data")
if not os.path.exists(leave_dir):
    os.makedirs(leave_dir)
combined_dir = os.path.join(weights_dir + "/combined_data")
if not os.path.exists(combined_dir):
    os.makedirs(combined_dir)

dic_dir = os.path.join(outdir, 'dictionaries')
if not os.path.exists(dic_dir):
    os.makedirs(dic_dir)

# %% [markdown]
# SETTING THE REWEIGHTING KEYS (DATA TYPES TO USE IN THE REWEIGHTING PROCEDURE)

# %%
colors = {'C': 'royalblue','HA': 'orange', 'CA': 'red',  'CB': 'forestgreen', 'H': 'mediumorchid', 'N': 'darkslateblue', 'JHNHA': 'cornflowerblue', 
'JCC': 'pink', 'Rg': 'grey', 'RDC': 'firebrick', 'RDC_Q': 'firebrick', 'SAXS':'teal', 'PRE_18': 'mediumslateblue', 'PRE_24':'mediumpurple',
 'PRE_42': 'rebeccapurple', 'PRE_62': 'fuchsia',
 'PRE_87':'darkviolet',
 'PRE_103': 'plum',
 'Tot': 'black'}

chemical_shifts = ['CB', 'HA', 'CA', 'H', 'N', 'C']
theta_0 = {'HA': 1., 'CA': 1, 'CB': 1., 'C': 1., 'H': 1., 'HA2': 1., 'HA3': 1., 'N': 1.,
               'RDC': 1., 'Rg': 1., 'JHNHA': 1., 'JCC': 1., 'SAXS': 1.,
               'PRE_24': 1., 'PRE_42': 1., 'PRE_62': 1., 'PRE_87': 1.,
                'PRE_103': 1.}

to_remove = ['HA', 'HA2', 'HA3']
reweighting_keys = ['CA', 'CB', 'H', 'C', 'N', 'RDC', 'JHNHA', 'JCC',
                    'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87',
                    'PRE_103', 'SAXS']

print('Main settings:\n')
print('Reweighting keys: {}'.format(reweighting_keys))
# Out:
# Main settings:
#
# Reweighting keys: ['CA', 'CB', 'H', 'C', 'N', 'RDC', 'JHNHA', 'JCC', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103', 'SAXS']

# %% [markdown]
# LOADING THE EXPERIMENTAL AND COMPUTED DATA

# %%
# chemical shifts
expdata = read_exp_cs(join(expdatadir, 'CS.exp.dat'))
compdata = read_cs_md(join(datadir, 'chemical_shifts.all.csv'), )
# RDC
expdata = add_exp_data(join(expdatadir, 'RDC.exp.dat'), expdata, 'RDC')
compdata = add_md_data(join(datadir, 'RDC.all.csv'), compdata, 'RDC')

# J_couplings
expdata = add_exp_data(expdatadir + '/JHNHA.exp.dat', expdata, 'JHNHA')
compdata = add_md_data(datadir + '/J_HNHA1.all.csv', compdata, 'JHNHA')

expdata = add_exp_data(expdatadir + '/JCC.exp.dat', expdata, 'JCC')
compdata = add_md_data(datadir + '/J_CC.all.csv', compdata, 'JCC')

# SAXS
expdata = add_exp_data(expdatadir + '/SAXS.exp.dat', expdata, 'SAXS')
compdata = add_md_data(datadir + '/SAXS.csv', compdata, 'SAXS')

# PREs

expdata = add_exp_data(expdatadir + '/Iratio-label-24.exp.dat', expdata, 'PRE_24')
compdata = add_md_data(datadir + '/Iratio-label-24.all.csv', compdata, 'PRE_24')

expdata = add_exp_data(expdatadir + '/Iratio-label-42.exp.dat', expdata, 'PRE_42')
compdata = add_md_data(datadir + '/Iratio-label-42.all.csv', compdata, 'PRE_42')

expdata = add_exp_data(expdatadir + '/Iratio-label-62.exp.dat', expdata, 'PRE_62')
compdata = add_md_data(datadir + '/Iratio-label-62.all.csv', compdata, 'PRE_62')

expdata = add_exp_data(expdatadir + '/Iratio-label-87.exp.dat', expdata, 'PRE_87')
compdata = add_md_data(datadir + '/Iratio-label-87.all.csv', compdata, 'PRE_87')

expdata = add_exp_data(expdatadir + '/Iratio-label-103.exp.dat', expdata, 'PRE_103')
compdata = add_md_data(datadir + '/Iratio-label-103.all.csv', compdata, 'PRE_103')

# Elimination of compdata that are not in expdata and viceversa
compdata, expdata = Align_Comp_Exp_Data(compdata, expdata)

####### TRAJ-related quantities

nframes = len(compdata[list(compdata.keys())[1]][list(compdata[list(compdata.keys())[1]].keys())[0]])

# labels
exp_labels = list(compdata.keys())
true_exp_labels = [key for key in exp_labels if key not in to_remove]

print(
    'Correctely acquired data from experiments and for MD simulations for the following quantities:\n{}\nNumber of frames = {}'.format(
        [str(key) for key in compdata.keys()], nframes))
# Out:
# Correctely acquired data from experiments and for MD simulations for the following quantities:
# ['HA', 'CA', 'CB', 'C', 'H', 'HA2', 'HA3', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# Number of frames = 29976

# %% [markdown]
# SETTING ALL THE DATA INTO DICTIONARIES AND ALIGNING THE DATA TO MATCH AND CALCULATING THE SIGMA MD

# %%
keys_list = []
for keys in expdata['SAXS'].keys():
    keys_list.append(keys)

first_key_value = expdata['SAXS']['0.0097']

for i in keys_list:
    expdata['SAXS'][i] = np.array(expdata['SAXS'][i]) / first_key_value

first_key_series = compdata['SAXS']['0.0097']

for i in keys_list:
    compdata['SAXS'][i] = (compdata['SAXS'][i]) / first_key_series

# %%
sd = {}
To_Scan = reweighting_keys
for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    print('Reweight Data = {}'.format(CS))
    print('Validation Data = {}'.format(Validation_Data))

    ### debugging variables
    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}
    compare_dict_v = {key: {} for key in compdata.keys()}

    ####### B) The reweighting procedure

    # i) Process Reweight data into arrays 
    obs_exp_r, traj_r, err_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays(Reweight_Data,
                                                                                                expdata, compdata,
                                                                                                theta_0,
                                                                                                compare_dict_r)

    # ii) Process Validation data into arrays 
    obs_exp_v, traj_v, err_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays(Validation_Data,
                                                                                                expdata, compdata,
                                                                                                theta_0,
                                                                                                compare_dict_v)

    # final_weights

    for key in data_v_type:
        print(key)
        res = []
        md_ave = []
        sigmas = []
        exp = []
        sd[key] = {}
        for key2 in compare_dict_v[key]:
            timeseries = compare_dict_v[key][key2][1]
            uniform_weights = np.ones(len(timeseries))
            dim = 5000
            A, W = Weighted_Independent_Blocks(timeseries, uniform_weights, dim, verbose=False)
            ave = np.average(A, weights=W)
            sigma = Weighted_Sigma_of_Mean(A, W)
            sd[key][key2] = np.array([float(key2), float(compare_dict_v[key][key2][0]), float(ave), float(sigma)])

    for key in data_r_type:
        print(key)
        res = []
        md_ave = []
        sigmas = []
        exp = []
        sd[key] = {}
        for key2 in compare_dict_r[key]:
            timeseries = compare_dict_r[key][key2][1]
            uniform_weights = np.ones(len(timeseries))
            dim = 5000
            A, W = Weighted_Independent_Blocks(timeseries, uniform_weights, dim, verbose=False)
            ave = np.average(A, weights=W)
            sigma = Weighted_Sigma_of_Mean(A, W)
            sd[key][key2] = np.array([float(key2), float(compare_dict_r[key][key2][0]), float(ave), float(sigma)])
# Out:
# Reweight Data = CA
# Validation Data = ['CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# CA
# Reweight Data = CB
# Validation Data = ['CA', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# CB
# Reweight Data = H
# Validation Data = ['CA', 'CB', 'C', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# H
# Reweight Data = C
# Validation Data = ['CA', 'CB', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# C
# Reweight Data = N
# Validation Data = ['CA', 'CB', 'C', 'H', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# N
# Reweight Data = RDC
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# RDC
# Reweight Data = JHNHA
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# JHNHA
# Reweight Data = JCC
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# JCC
# Reweight Data = PRE_24
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# PRE_24
# Reweight Data = PRE_42
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_62
# PRE_87
# PRE_103
# PRE_42
# Reweight Data = PRE_62
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_87
# PRE_103
# PRE_62
# Reweight Data = PRE_87
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_103
# PRE_87
# Reweight Data = PRE_103
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# Reweight Data = SAXS
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# SAXS

# %% [markdown]
# INITIAL ROUND OF REWEIGHTING FOR A RANGE OF SIGMA_REG VALUES FOR EACH INDIVIDUAL DATA TYPE

# %%
To_Scan = reweighting_keys
thetas = np.linspace(0.001, 20, 200)
ref_theta = thetas[-1]
RMSE_dict = {}
KishScan_one_data = {}


for CS in To_Scan:
        CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
        KishScan_one_data[CS] = {}
        print('Reweight Data = {}'.format(CS))
        RMSE_dict[CS] = {}

        ### debugging variables
        compare = []
        compare_dict_r = {key: {} for key in compdata.keys()}
        compare_dict_v = {key: {} for key in compdata.keys()}

        ####### B) The reweighting procedure

        obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(
            Reweight_Data, expdata, compdata, theta_0, sd, compare_dict_r)
        obs_exp_v, traj_v, err_v, sigma_md_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays_with_sigma(
            Validation_Data, expdata, compdata, theta_0, sd, compare_dict_v)

        # THETA CYCLE
        theta_list = []
        kish_list = []
        rmsd_f_list = []
        for theta_m in np.flip(thetas):

            s = '{:.2f}'.format(theta_m)
            # print(s)
            sigma_reg = theta_m * err_r
            sigma_md = sigma_md_r
            RMSE_dict[CS][s] = {}

            # iv) Print dimensions
            nobs_r = len(obs_exp_r)
            nobs_v = len(obs_exp_v)
            # Print_Number_of_Data(nframes, nobs_r, nobs_v, data_r_type, data_v_type)

            # v) perform minimization
            # OBS: res.X = lagrange multiplier
            weight_bias = np.ones(nframes)

            if 'RDC' in Reweight_Data:
                initial_weights = weight_bias
                initial_weights /= np.sum(initial_weights)
                initial_obs_r = np.dot(traj_r, initial_weights)
                initial_obs_r
                exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
                calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
                qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
                qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

                if (qf_neg < qf_pos):
                    c = -c_neg
                else:
                    c = c_pos

                RDC_rows = np.where(data_r_type['RDC'] == 1)
                traj_r[RDC_rows] = traj_r[RDC_rows] * c

            if 'RDC' in Validation_Data:
                initial_weights = weight_bias
                initial_weights /= np.sum(initial_weights)
                initial_obs_v = np.dot(traj_v, initial_weights)
                exp_rdc = np.trim_zeros(obs_exp_v * data_v_type['RDC'])
                calc_rdc = np.trim_zeros(initial_obs_v * data_v_type['RDC'])
                qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
                qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

                if (qf_neg < qf_pos):
                    c = -c_neg
                else:
                    c = c_pos

                RDC_rows = np.where(data_v_type['RDC'] == 1)
                traj_v[RDC_rows] = traj_v[RDC_rows] * c

            res = sp.optimize.minimize(func_sigma_reg_sigma_md,
                                       args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                       x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
            initial_weights = Normalize_Weights(weight_bias)
            initial_obs_r = np.dot(traj_r, initial_weights)
            initial_obs_v = np.dot(traj_v, initial_weights)

            final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
            final_obs_r = np.dot(traj_r, final_weights)
            final_obs_v = np.dot(traj_v, final_weights)
            # g) calculating Kish effective size
            Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
            Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)

            Kish_ratio = (Ks_a / Ks_b) * 100
            RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
            RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

            theta_list.append(theta_m)
            kish_list.append(Kish_ratio)
            rmsd_f_list.append(RMSE_reweight)
            RMSE_r_i = {}
            RMSE_v_i = {}
            RMSE_r_f = {}
            RMSE_v_f = {}
            RMSE_r_i['Tot'] = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))

            for t in data_r_type:
                RMSE_r_i[t] = np.sqrt(
                    np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
                if str(t) == 'RDC':
                    qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                       obs_exp_r * data_r_type['RDC'])
                    RMSE_r_i['RDC'] = qf

            RMSE_v_i['Tot'] = np.sqrt(
                np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            for t in data_v_type:
                RMSE_v_i[t] = np.sqrt(
                    np.sum((initial_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t]))
                if str(t) == 'RDC':
                    qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_v * data_v_type['RDC'],
                                                                       obs_exp_v * data_v_type['RDC'])
                    RMSE_v_i['RDC'] = qf

            RMSE_r_f['Tot'] = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

            for t in data_r_type:
                RMSE_r_f[t] = np.sqrt(np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
                if str(t) == 'RDC':
                    qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                       obs_exp_r * data_r_type['RDC'])
                    RMSE_r_f['RDC'] = qf

            for t in data_v_type:
                RMSE_v_f[t] = np.sqrt(np.sum((final_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t]))
                if str(t) == 'RDC':
                    qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_v * data_v_type['RDC'],
                                                                       obs_exp_v * data_v_type['RDC'])
                    RMSE_v_f['RDC'] = qf

            RMSE_dict[CS][s]['Kish'] = Kish_ratio
            RMSE_dict[CS][s]['r_i'] = RMSE_r_i
            RMSE_dict[CS][s]['r_f'] = RMSE_r_f
            RMSE_dict[CS][s]['v_i'] = RMSE_v_i
            RMSE_dict[CS][s]['v_f'] = RMSE_v_f

        KishScan_one_data[CS]['kish'] = np.column_stack((theta_list, kish_list))
        KishScan_one_data[CS]['rmsd'] = np.column_stack((theta_list, rmsd_f_list))
# Out:
# Reweight Data = CA
# Reweight Data = CB
# Reweight Data = H
# Reweight Data = C
# Reweight Data = N
# Reweight Data = RDC
# Reweight Data = JHNHA
# Reweight Data = JCC
# Reweight Data = PRE_24
# Reweight Data = PRE_42
# Reweight Data = PRE_62
# Reweight Data = PRE_87
# Reweight Data = PRE_103
# Reweight Data = SAXS

# %% [markdown]
# FINDING OUT THE OPTIMAL VALUE OF SIGMA_REG FOR EACH DATA TYPE BASED ON DESIRED ENSEMBLE SIZE (KISH=10/ KISH RATIO = 0.1)

# %%
kish_min = 10
theta_dict = {}
Kish_ratio_vals = []
for key in KishScan_one_data:
    k = KishScan_one_data[key]['kish']
    b = (np.where(k[:, 1] >= kish_min))[0]
    idx = b[-1]
    idy = b[-2]
    theta_m = k[idx][0]
    Kish_ratio_vals.append(theta_m)
    if (theta_m == 0):
        theta_m = k[idy][0]
    theta_dict[key] = {}
    theta_dict[key] = (theta_m)

# %%
def print_results():
    print(CS, "Theta:", theta_m, "Kish: %9.6lf" % (Kish_ratio), "RMSD initail: %0.4f" % RMSE_initial,
            "RMSD final: %0.4f" % RMSE_reweight)

    print("Initial RMSE reweight data ")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))

        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])

            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Initial RMSE validation data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_v - obs_exp_v) ** 2)))

    for t in data_v_type:
        print(" *    %2s :" % t, end='')
  
        print("     %6.3lf" % np.sqrt(
            np.sum((initial_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_v * data_v_type['RDC'],
                                                                obs_exp_v * data_v_type['RDC'])
 
            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE reweight data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdcs_scale_f, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])

            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE validation data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_v - obs_exp_v) ** 2)))

    for t in data_v_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((final_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_f, c = scale_rdc_Q(final_obs_v * data_v_type['RDC'],
                                                                obs_exp_v * data_v_type['RDC'])
           
            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)

# %% [markdown]
# SECOND ROUND OF REWEIGHTING BASED ON OPTIMAL VALUES OF THE PARAMETERS

# %%
To_Scan = reweighting_keys

for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    print('Reweight Data = {}'.format(CS))
    CS_dir = join(single_dir, CS)
    if not os.path.exists(CS_dir):
        os.makedirs(CS_dir)

    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}
    compare_dict_v = {key: {} for key in compdata.keys()}

    obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(
        Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)
    obs_exp_v, traj_v, err_v, sigma_md_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays_with_sigma(
        Validation_Data, expdata, compdata, theta_0, sd, compare_dict_v)

    theta_m = theta_dict[CS]
    s = '{:.2f}'.format(theta_m)
    print(s)
    sigma_reg = theta_m
    sigma_md = sigma_md_r

    # iv) Print dimensions
    nobs_r = len(obs_exp_r)
    nobs_v = len(obs_exp_v)

    # v) perform minimization
    # OBS: res.X = lagrange multiplier
    weight_bias = np.ones(nframes)
    if 'RDC' in Reweight_Data:
        intial_weights = weight_bias
        initial_weights /= np.sum(initial_weights)
        initial_obs_r = np.dot(traj_r, initial_weights)
        initial_obs_r
        exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
        calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
        qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
        qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

        if (qf_neg < qf_pos):
            c = -c_neg
        else:
            c = c_pos
        RDC_rows = np.where(data_r_type['RDC'] == 1)
        traj_r[RDC_rows] = traj_r[RDC_rows] * c

    if 'RDC' in Validation_Data:
        intial_weights = weight_bias
        initial_weights /= np.sum(initial_weights)
        initial_obs_v = np.dot(traj_v, initial_weights)
        initial_obs_v
        exp_rdc = np.trim_zeros(obs_exp_v * data_v_type['RDC'])
        calc_rdc = np.trim_zeros(initial_obs_v * data_v_type['RDC'])
        qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
        qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

        if (qf_neg < qf_pos):
            c = -c_neg
        else:
            c = c_pos
        RDC_rows = np.where(data_v_type['RDC'] == 1)
        traj_v[RDC_rows] = traj_v[RDC_rows] * c

    res = sp.optimize.minimize(func_sigma_reg_sigma_md, args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
    initial_weights = Normalize_Weights(weight_bias)
    initial_obs_r = np.dot(traj_r, initial_weights)
    initial_obs_v = np.dot(traj_v, initial_weights)
    final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
    # e) final average observables for reweighting and validation
    final_obs_r = np.dot(traj_r, final_weights)
    final_obs_v = np.dot(traj_v, final_weights)
    # g) calculating Kish effective size
    Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
    Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)
    Kish_ratio = (Ks_a / Ks_b) * 100
    RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
    RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))
    print_results()

    np.savetxt('%s/weights_final.dat' % (CS_dir), final_weights, fmt=" %6.12lf")
    # print final weights to file

    f = open("%s/weights_final.a.dat" % CS_dir, "w")
    for w in final_weights:
        f.write("%e\n" % w)
    f.close()
# Out:
# Reweight Data = CA
# 2.41
# CA Theta: 2.4129396984924623 Kish: 11.983596 RMSD initail: 0.7599 RMSD final: 0.5490
# Initial RMSE reweight data
#  * Total :      0.760
#  *    CA :      0.760
# Initial RMSE validation data
#  * Total :      1.284
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.549
#  *    CA :      0.549
# Final RMSE validation data
#  * Total :      1.135
#  *    CB :      1.224
#  *     C :      0.596
#  *     H :      0.227
#  *     N :      1.650
#  *    RDC :      2.921
#  *    RDC Q_scaled:  0.611
#  *    JHNHA :      0.790
#  *    JCC :      0.265
#  *    SAXS :      0.176
#  *    PRE_24 :      0.346
#  *    PRE_42 :      0.436
#  *    PRE_62 :      0.235
#  *    PRE_87 :      0.301
#  *    PRE_103 :      0.270
# Reweight Data = CB
# 3.32
# CB Theta: 3.3174170854271354 Kish: 12.280969 RMSD initail: 1.2644 RMSD final: 1.0853
# Initial RMSE reweight data
#  * Total :      1.264
#  *    CB :      1.264
# Initial RMSE validation data
#  * Total :      1.240
#  *    CA :      0.760
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      1.085
#  *    CB :      1.085
# Final RMSE validation data
#  * Total :      1.176
#  *    CA :      0.705
#  *     C :      0.566
#  *     H :      0.233
#  *     N :      1.809
#  *    RDC :      3.198
#  *    RDC Q_scaled:  0.682
#  *    JHNHA :      0.807
#  *    JCC :      0.214
#  *    SAXS :      0.182
#  *    PRE_24 :      0.332
#  *    PRE_42 :      0.455
#  *    PRE_62 :      0.235
#  *    PRE_87 :      0.326
#  *    PRE_103 :      0.242
# Reweight Data = H
# 0.91
# H Theta: 0.9054773869346733 Kish: 11.083345 RMSD initail: 0.2651 RMSD final: 0.1952
# Initial RMSE reweight data
#  * Total :      0.265
#  *     H :      0.265
# Initial RMSE validation data
#  * Total :      1.305
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.195
#  *     H :      0.195
# Final RMSE validation data
#  * Total :      1.151
#  *    CA :      0.643
#  *    CB :      1.188
#  *     C :      0.581
#  *     N :      1.628
#  *    RDC :      2.954
#  *    RDC Q_scaled:  0.614
#  *    JHNHA :      0.813
#  *    JCC :      0.246
#  *    SAXS :      0.170
#  *    PRE_24 :      0.343
#  *    PRE_42 :      0.430
#  *    PRE_62 :      0.228
#  *    PRE_87 :      0.299
#  *    PRE_103 :      0.236
# Reweight Data = C
# 2.11
# C Theta: 2.1114472361809042 Kish: 12.880020 RMSD initail: 0.6433 RMSD final: 0.5259
# Initial RMSE reweight data
#  * Total :      0.643
#  *     C :      0.643
# Initial RMSE validation data
#  * Total :      1.290
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.526
#  *     C :      0.526
# Final RMSE validation data
#  * Total :      1.172
#  *    CA :      0.664
#  *    CB :      1.153
#  *     H :      0.227
#  *     N :      1.727
#  *    RDC :      3.052
#  *    RDC Q_scaled:  0.637
#  *    JHNHA :      0.797
#  *    JCC :      0.217
#  *    SAXS :      0.171
#  *    PRE_24 :      0.332
#  *    PRE_42 :      0.437
#  *    PRE_62 :      0.224
#  *    PRE_87 :      0.310
#  *    PRE_103 :      0.230
# Reweight Data = N
# 6.53
# N Theta: 6.533336683417085 Kish: 10.162044 RMSD initail: 2.0410 RMSD final: 1.3540
# Initial RMSE reweight data
#  * Total :      2.041
#  *     N :      2.041
# Initial RMSE validation data
#  * Total :      1.120
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      1.354
#  *     N :      1.354
# Final RMSE validation data
#  * Total :      1.020
#  *    CA :      0.623
#  *    CB :      1.212
#  *     C :      0.590
#  *     H :      0.217
#  *    RDC :      2.941
#  *    RDC Q_scaled:  0.620
#  *    JHNHA :      0.838
#  *    JCC :      0.260
#  *    SAXS :      0.175
#  *    PRE_24 :      0.352
#  *    PRE_42 :      0.429
#  *    PRE_62 :      0.230
#  *    PRE_87 :      0.301
#  *    PRE_103 :      0.267
# Reweight Data = RDC
# 8.64
# RDC Theta: 8.643783919597988 Kish: 10.416078 RMSD initail: 3.2343 RMSD final: 2.3431
# Initial RMSE reweight data
#  * Total :      3.234
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
# Initial RMSE validation data
#  * Total :      0.891
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      2.343
#  *    RDC :      2.343
#  *    RDC Q_scaled:  0.473
# Final RMSE validation data
#  * Total :      0.799
#  *    CA :      0.657
#  *    CB :      1.247
#  *     C :      0.612
#  *     H :      0.234
#  *     N :      1.753
#  *    JHNHA :      0.870
#  *    JCC :      0.261
#  *    SAXS :      0.172
#  *    PRE_24 :      0.350
#  *    PRE_42 :      0.453
#  *    PRE_62 :      0.261
#  *    PRE_87 :      0.316
#  *    PRE_103 :      0.219
# Reweight Data = JHNHA
# 2.81
# JHNHA Theta: 2.814929648241206 Kish: 10.587084 RMSD initail: 0.9526 RMSD final: 0.6227
# Initial RMSE reweight data
#  * Total :      0.953
#  *    JHNHA :      0.953
# Initial RMSE validation data
#  * Total :      1.254
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.623
#  *    JHNHA :      0.623
# Final RMSE validation data
#  * Total :      1.164
#  *    CA :      0.666
#  *    CB :      1.189
#  *     C :      0.589
#  *     H :      0.233
#  *     N :      1.809
#  *    RDC :      3.077
#  *    RDC Q_scaled:  0.659
#  *    JCC :      0.243
#  *    SAXS :      0.177
#  *    PRE_24 :      0.338
#  *    PRE_42 :      0.452
#  *    PRE_62 :      0.248
#  *    PRE_87 :      0.314
#  *    PRE_103 :      0.223
# Reweight Data = JCC
# 0.80
# JCC Theta: 0.8049798994974874 Kish: 11.841015 RMSD initail: 0.2733 RMSD final: 0.1669
# Initial RMSE reweight data
#  * Total :      0.273
#  *    JCC :      0.273
# Initial RMSE validation data
#  * Total :      1.274
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.167
#  *    JCC :      0.167
# Final RMSE validation data
#  * Total :      1.202
#  *    CA :      0.719
#  *    CB :      1.163
#  *     C :      0.580
#  *     H :      0.245
#  *     N :      1.878
#  *    RDC :      3.117
#  *    RDC Q_scaled:  0.673
#  *    JHNHA :      0.837
#  *    SAXS :      0.176
#  *    PRE_24 :      0.321
#  *    PRE_42 :      0.466
#  *    PRE_62 :      0.262
#  *    PRE_87 :      0.327
#  *    PRE_103 :      0.201
# Reweight Data = PRE_24
# 0.80
# PRE_24 Theta: 0.8049798994974874 Kish: 13.894073 RMSD initail: 0.3234 RMSD final: 0.1862
# Initial RMSE reweight data
#  * Total :      0.323
#  *    PRE_24 :      0.323
# Initial RMSE validation data
#  * Total :      1.282
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.186
#  *    PRE_24 :      0.186
# Final RMSE validation data
#  * Total :      1.360
#  *    CA :      0.842
#  *    CB :      1.278
#  *     C :      0.673
#  *     H :      0.294
#  *     N :      2.243
#  *    RDC :      3.394
#  *    RDC Q_scaled:  0.744
#  *    JHNHA :      0.982
#  *    JCC :      0.271
#  *    SAXS :      0.173
#  *    PRE_42 :      0.522
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.338
#  *    PRE_103 :      0.187
# Reweight Data = PRE_42
# 1.61
# PRE_42 Theta: 1.6089597989949747 Kish: 12.001839 RMSD initail: 0.5007 RMSD final: 0.3918
# Initial RMSE reweight data
#  * Total :      0.501
#  *    PRE_42 :      0.501
# Initial RMSE validation data
#  * Total :      1.278
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.392
#  *    PRE_42 :      0.392
# Final RMSE validation data
#  * Total :      1.175
#  *    CA :      0.664
#  *    CB :      1.196
#  *     C :      0.582
#  *     H :      0.226
#  *     N :      1.736
#  *    RDC :      3.085
#  *    RDC Q_scaled:  0.651
#  *    JHNHA :      0.821
#  *    JCC :      0.248
#  *    SAXS :      0.164
#  *    PRE_24 :      0.346
#  *    PRE_62 :      0.220
#  *    PRE_87 :      0.292
#  *    PRE_103 :      0.241
# Reweight Data = PRE_62
# 0.80
# PRE_62 Theta: 0.8049798994974874 Kish: 12.091442 RMSD initail: 0.2991 RMSD final: 0.1434
# Initial RMSE reweight data
#  * Total :      0.299
#  *    PRE_62 :      0.299
# Initial RMSE validation data
#  * Total :      1.282
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.143
#  *    PRE_62 :      0.143
# Final RMSE validation data
#  * Total :      1.196
#  *    CA :      0.664
#  *    CB :      1.171
#  *     C :      0.583
#  *     H :      0.242
#  *     N :      1.747
#  *    RDC :      3.153
#  *    RDC Q_scaled:  0.660
#  *    JHNHA :      0.835
#  *    JCC :      0.277
#  *    SAXS :      0.179
#  *    PRE_24 :      0.375
#  *    PRE_42 :      0.416
#  *    PRE_87 :      0.319
#  *    PRE_103 :      0.332
# Reweight Data = PRE_87
# 1.11
# PRE_87 Theta: 1.106472361809045 Kish: 11.160301 RMSD initail: 0.3331 RMSD final: 0.2514
# Initial RMSE reweight data
#  * Total :      0.333
#  *    PRE_87 :      0.333
# Initial RMSE validation data
#  * Total :      1.280
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.251
#  *    PRE_87 :      0.251
# Final RMSE validation data
#  * Total :      1.206
#  *    CA :      0.695
#  *    CB :      1.231
#  *     C :      0.613
#  *     H :      0.238
#  *     N :      1.866
#  *    RDC :      3.086
#  *    RDC Q_scaled:  0.673
#  *    JHNHA :      0.872
#  *    JCC :      0.265
#  *    SAXS :      0.166
#  *    PRE_24 :      0.316
#  *    PRE_42 :      0.437
#  *    PRE_62 :      0.262
#  *    PRE_103 :      0.211
# Reweight Data = PRE_103
# 0.40
# PRE_103 Theta: 0.4029899497487437 Kish: 18.604980 RMSD initail: 0.1861 RMSD final: 0.1122
# Initial RMSE reweight data
#  * Total :      0.186
#  *    PRE_103 :      0.186
# Initial RMSE validation data
#  * Total :      1.282
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    SAXS :      0.180
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
# Final RMSE reweight data
#  * Total :      0.112
#  *    PRE_103 :      0.112
# Final RMSE validation data
#  * Total :      1.351
#  *    CA :      0.812
#  *    CB :      1.296
#  *     C :      0.673
#  *     H :      0.285
#  *     N :      2.203
#  *    RDC :      3.389
#  *    RDC Q_scaled:  0.741
#  *    JHNHA :      0.988
#  *    JCC :      0.288
#  *    SAXS :      0.162
#  *    PRE_24 :      0.317
#  *    PRE_42 :      0.492
#  *    PRE_62 :      0.326
#  *    PRE_87 :      0.332
# Reweight Data = SAXS
# 0.40
# SAXS Theta: 0.4029899497487437 Kish: 12.805118 RMSD initail: 0.1804 RMSD final: 0.1446
# Initial RMSE reweight data
#  * Total :      0.180
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      1.260
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      0.145
#  *    SAXS :      0.145
# Final RMSE validation data
#  * Total :      1.225
#  *    CA :      0.740
#  *    CB :      1.251
#  *     C :      0.626
#  *     H :      0.259
#  *     N :      2.024
#  *    RDC :      3.117
#  *    RDC Q_scaled:  0.685
#  *    JHNHA :      0.911
#  *    JCC :      0.264
#  *    PRE_24 :      0.303
#  *    PRE_42 :      0.452
#  *    PRE_62 :      0.279
#  *    PRE_87 :      0.309
#  *    PRE_103 :      0.153

# %% [markdown]
# DOING REWEIGHTING ON A RANGE OF PARAMETER VALUES AFTER COMBINING ALL DATA

# %%
combined_reweighting_keys = [reweighting_keys]
print('Reweighting keys: {}'.format(combined_reweighting_keys))

To_Scan = combined_reweighting_keys
thetas = np.linspace(0.01, 20, 20)
ref_theta = thetas[-1]
RMSE_dict_combined = {}
KishScan_combined = {}
for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    KishScan_combined[CS] = {}
    CS_dir = join(combined_dir, CS)
    if not os.path.exists(CS_dir):
        os.makedirs(CS_dir)
    print('Reweight Data = {}'.format(CS))
    RMSE_dict_combined[CS] = {}
    combined_key_string = CS

    ### debugging variables
    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}

    ####### B) The reweighting procedure

    obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(
        Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)
    # THETA CYCLE
    theta_list = []
    kish_list = []
    rmsd_f_list = []
    for theta_m in np.flip(thetas):

        s = '{:.2f}'.format(theta_m)
        print(s)
        sigma_reg = theta_m * err_r
        sigma_md = sigma_md_r
        RMSE_dict_combined[CS][s] = {}

        # iv) Print dimensions
        nobs_r = len(obs_exp_r)
        nobs_v = len(obs_exp_v)
        # Print_Number_of_Data(nframes, nobs_r, nobs_v, data_r_type, data_v_type)

        # v) perform minimization
        # OBS: res.X = lagrange multiplier
        weight_bias = np.ones(nframes)
        if 'RDC' in Reweight_Data:
            initial_weights = weight_bias
            initial_weights /= np.sum(initial_weights)
            initial_obs_r = np.dot(traj_r, initial_weights)
            initial_obs_r
            exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
            calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
            qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
            qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

            if (qf_neg < qf_pos):
                c = -c_neg
            else:
                c = c_pos

            RDC_rows = np.where(data_r_type['RDC'] == 1)
            traj_r[RDC_rows] = traj_r[RDC_rows] * c

        res = sp.optimize.minimize(func_sigma_reg_sigma_md,
                                    args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                    x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
        initial_weights = Normalize_Weights(weight_bias)
        initial_obs_r = np.dot(traj_r, initial_weights)
        # if res.success: print("\nMinimization worked: {}\n".format(res.success))
        # else: raise ValueError('Minimization with {}, theta = {} as reweighting data did not worked!'.format(CS, s))
        final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
        # e) final average observables for reweighting and validation
        final_obs_r = np.dot(traj_r, final_weights)

        # g) calculating Kish effective size
        Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
        Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)

        Kish_ratio = (Ks_a / Ks_b) * 100
        RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
        RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))
        # print(CS,"Theta:",theta_m,"Kish: %9.6lf" % (Kish_ratio),"RMSD initail: %0.4f"%RMSE_initial,"RMSD final: %0.4f"%RMSE_reweight)
        theta_list.append(theta_m)
        kish_list.append(Kish_ratio)
        rmsd_f_list.append(RMSE_reweight)
        RMSE_r_i = {}
        RMSE_r_f = {}
        RMSE_r_i['Tot'] = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))

        for t in data_r_type:
            RMSE_r_i[t] = np.sqrt(
                np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                    obs_exp_r * data_r_type['RDC'])
                RMSE_r_i['RDC'] = qf

        RMSE_r_f['Tot'] = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))
        for t in data_r_type:
            RMSE_r_f[t] = np.sqrt(np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                    obs_exp_r * data_r_type['RDC'])
                RMSE_r_f['RDC'] = qf

        RMSE_dict_combined[CS][s]['Kish'] = Kish_ratio
        RMSE_dict_combined[CS][s]['r_i'] = RMSE_r_i
        RMSE_dict_combined[CS][s]['r_f'] = RMSE_r_f
    KishScan_combined[CS]['kish'] = np.column_stack((theta_list, kish_list))
    KishScan_combined[CS]['rmsd'] = np.column_stack((theta_list, rmsd_f_list))
# Out:
# Reweighting keys: [['CA', 'CB', 'H', 'C', 'N', 'RDC', 'JHNHA', 'JCC', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103', 'SAXS']]
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 20.00
# 18.95
# 17.90
# 16.84
# 15.79
# 14.74
# 13.69
# 12.64
# 11.58
# 10.53
# 9.48
# 8.43
# 7.37
# 6.32
# 5.27
# 4.22
# 3.17
# 2.11
# 1.06
# 0.01

# %% [markdown]
# FINDING THE OPTIMAL PARAMETER FOR COMBINED REWEIGHTING

# %%
kish_min = 10
theta_dict_combined = {}
Kish_ratio_vals = []
for key in KishScan_combined:
    k = KishScan_combined[key]['kish']
    b = (np.where(k[:, 1] >= kish_min))[0]
    idx = b[-1]
    idy = b[-2]
    theta_m = k[idx][0]
    Kish_ratio_vals.append(theta_m)
    if (theta_m == 0):
        theta_m = k[idy][0]
    theta_dict_combined[key] = {}
    theta_dict_combined[key] = (theta_m)
    print(key, theta_m)
# Out:
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS 4.218421052631578

# %%
def print_comb_results():
    print(CS, "Theta:", theta_m, "Kish: %9.6lf" % (Kish_ratio), "RMSD initail: %0.4f" % RMSE_initial,
          "RMSD final: %0.4f" % RMSE_reweight)

    # Iniitial RMSE and Sigma
    print("Initial RMSE reweight data ")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print(
            "     %6.3lf" % np.sqrt(np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))

        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                               obs_exp_r * data_r_type['RDC'])
            # print(" *    RDC scaled RMSD:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE reweight data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdcs_scale_f, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])
            # print(" *    RDC RMSE_scale:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)

# %% [markdown]
# FUNCTION TO PLOT THE FITTING DATA

# %%
PREs = ['PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
from matplotlib.ticker import StrMethodFormatter

def plot_fitting_data(weights):
    for t in Reweight_Data:
        if t != 'Rg':
            print(t)
            resid = []
            exp = []
            for i, id in enumerate(compare_dict_r[t]):
                resid.append(float(id))
            initial = np.trim_zeros(initial_obs_r * data_r_type[t])
            reweight = np.trim_zeros(final_obs_r * data_r_type[t])
            exp = np.trim_zeros(obs_exp_r * data_r_type[t])
            rmsd_i = (sum(np.square(initial - exp)) / len(exp)) ** 0.5
            rmsd_f = (sum(np.square(reweight - exp)) / len(exp)) ** 0.5
            print("RMSD_initial:%6.3lf" % rmsd_i, "RMSD_final:%6.3lf" % rmsd_f)
    
            if t == 'RDC':
                qi_initial, rms_initial, qf_initial, rms_f_initial, rdc_scale_i_initial, c = scale_rdc_Q(exp, initial)
                qi_reweight, rms_i_reweight, qf_reweight, rms_f_reweight, rdc_scale_i_reweight, c = scale_rdc_Q(exp,
                                                                                                                reweight)
                print("RMSD initial scale:%6.3lf" % rms_f_initial, "RMSD final scale:%6.3lf" % rms_f_reweight)
                print("Q initial scale:%6.3lf" % qf_initial, "Q final scale:%6.3lf" % qf_reweight)
                plt.plot(np.asarray(resid), initial, color='red', label="Unbiased")
                plt.plot(np.asarray(resid), reweight, color='darkred', label="Reweighted", linestyle='dashed')
                plt.plot(np.asarray(resid), exp, color='black', label='Exp')
                plt.ylabel(r'$D_{N-HN}$(Hz)', size=18)
                plt.title('%s' % t, size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.grid()
                plt.xlabel('Residues', size=18)
                plt.legend( loc='upper right', fontsize=12)
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

            elif t == 'SAXS':
                plt.gca().xaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}'))
                plt.plot(np.asarray(resid), initial, color='red', label="Unbiased")
                plt.plot(np.asarray(resid), reweight, color='darkred', linestyle='dashed' ,label="Reweighted")
                plt.plot(np.asarray(resid), exp, color='black', label='Exp')
                plt.ylabel('Peak Intensity', size=18)
                plt.title('%s' % t, size='20')
                plt.xticks(size='12')
                plt.yticks(size='12')
                plt.grid()
                plt.xlabel('Scattering angle (q)', size=18, labelpad=7)
                plt.legend(loc='upper right', fontsize=12)
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()
            elif t == 'CA':
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$CS_{calc}$- $CS_{exp}$|', size=20)
                plt.title(r"C$\alpha$", size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.grid()
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

            elif t == 'CB':
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$CS_{calc}$- $CS_{exp}$|', size=20)
                plt.title(r"C$\beta$", size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.grid()
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

            elif t == 'HA':
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$CS_{calc}$- $CS_{exp}$|', size=20)
                plt.title(r"H$\alpha$", size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.grid()
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

            elif t == "JHNHA":
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$^3J_{calc}$- $^3J_{exp}$|', size=20)
                plt.title(r"$^3JHNH\alpha$", size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.grid()
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.png'%(outdir,t), bbox_inches='tight')
                plt.show()

            elif t in PREs:

                plt.plot(np.asarray(resid), initial, color='red', label='Unbiased')
                plt.plot(np.asarray(resid), reweight, color='darkred', linestyle='dashed', label='Reweighted')
                plt.plot(np.asarray(resid), exp, color='black', label='Experiment')
                plt.ylabel('Peak Intensity', size=18)
                plt.title('%s' % t, size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.grid()
                plt.xlabel('Residue', size=18)
                plt.legend(bbox_to_anchor=(1, 1.0), loc='upper left', fontsize=12)
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf'%(outdir,t), bbox_inches='tight')
                plt.show()



            else:
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$CS_{calc}$- $CS_{exp}$|', size=20)
                plt.title('%s' % t, size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.grid()
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

# %% [markdown]
# REWEIGHTING WITH ALL THE DATA AND PLOTTING THE FIT TO EXPERIMENT

# %%
To_Scan=combined_reweighting_keys


CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(To_Scan[0], true_exp_labels)
obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)


s = '{:.2f}'.format(theta_m)

sigma_reg=theta_m*err_r
sigma_md=sigma_md_r
        

nobs_r = len(obs_exp_r)
nobs_v = len(obs_exp_v)
weight_bias=np.ones(nframes)
if 'RDC' in Reweight_Data:    
       initial_weights=weight_bias
       initial_weights/=np.sum(initial_weights)
       initial_obs_r=np.dot(traj_r,initial_weights)
       initial_obs_r
       exp_rdc=np.trim_zeros(obs_exp_r*data_r_type['RDC'])
       calc_rdc=np.trim_zeros(initial_obs_r*data_r_type['RDC'])
       qi_pos,rms_i_pos,qf_pos,rms_f_pos,rdc_scale_pos,c_pos=scale_rdc_Q(exp_rdc,calc_rdc)
       #print(qi_pos,rms_i_pos,qf_pos,rms_f_pos,rdc_scale_pos,c_pos)    
       qi_neg,rms_i_neg,qf_neg,rms_f_neg,rdc_scale_neg,c_neg=scale_rdc_Q(-exp_rdc,calc_rdc)
       #print(qi_neg,rms_i_neg,qf_neg,rms_f_neg,rdc_scale_neg,c_neg)

       if(qf_neg<qf_pos):
        c=-c_neg
       else: 
        c=c_pos
    
       RDC_rows=np.where(data_r_type['RDC']==1)
       traj_r[RDC_rows]=traj_r[RDC_rows]*c


res = sp.optimize.minimize(func_sigma_reg_sigma_md, args = (traj_r, obs_exp_r, weight_bias, sigma_reg,sigma_md), x0 =  np.zeros((nobs_r,)), method='L-BFGS-B',jac=True)
initial_weights = Normalize_Weights(weight_bias)
initial_obs_r=np.dot(traj_r,initial_weights)
final_weights = Normalize_Weights(weight_bias-np.dot(res.x,traj_r))
final_obs_r=np.dot(traj_r,final_weights)
Ks_b = np.average(initial_weights)**2/np.average(initial_weights**2)
Ks_a = np.average(final_weights)**2/np.average(final_weights**2)
        
Kish_ratio = (Ks_a/Ks_b)*100
RMSE_initial=np.sqrt(np.mean((initial_obs_r-obs_exp_r)**2))
RMSE_reweight=np.sqrt(np.mean((final_obs_r-obs_exp_r)**2))

plot_fitting_data(final_weights)
print_comb_results()

np.savetxt('%s/weights_final.dat' % (CS_dir), final_weights, fmt=" %6.12lf")
# print final weights to file

f = open("%s/weights_final.a.dat" % CS_dir, "w")
for w in final_weights:
       f.write("%e\n" % w)
f.close()
# Out:
# CA
# RMSD_initial: 0.760 RMSD_final: 0.691
# CB
# RMSD_initial: 1.264 RMSD_final: 1.213
# H
# RMSD_initial: 0.265 RMSD_final: 0.239
# C
# RMSD_initial: 0.643 RMSD_final: 0.596
# N
# RMSD_initial: 2.041 RMSD_final: 1.830
# RDC
# RMSD_initial: 3.234 RMSD_final: 3.031
# RMSD initial scale: 3.234 RMSD final scale: 2.984
# Q initial scale: 0.711 Q final scale: 0.656
# JHNHA
# RMSD_initial: 0.953 RMSD_final: 0.846
# JCC
# RMSD_initial: 0.273 RMSD_final: 0.238
# PRE_24
# RMSD_initial: 0.323 RMSD_final: 0.308
# PRE_42
# RMSD_initial: 0.501 RMSD_final: 0.457
# PRE_62
# RMSD_initial: 0.299 RMSD_final: 0.257
# PRE_87
# RMSD_initial: 0.333 RMSD_final: 0.314
# PRE_103
# RMSD_initial: 0.186 RMSD_final: 0.176
# SAXS
# RMSD_initial: 0.180 RMSD_final: 0.166
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 4.218421052631578 Kish: 39.057707 RMSD initail: 1.2420 RMSD final: 1.1489
# Initial RMSE reweight data
#  * Total :      1.242
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Final RMSE reweight data
#  * Total :      1.149
#  *    CA :      0.691
#  *    CB :      1.213
#  *     H :      0.239
#  *     C :      0.596
#  *     N :      1.830
#  *    RDC :      3.031
#  *    RDC Q_scaled:  0.656
#  *    JHNHA :      0.846
#  *    JCC :      0.238
#  *    PRE_24 :      0.308
#  *    PRE_42 :      0.457
#  *    PRE_62 :      0.257
#  *    PRE_87 :      0.314
#  *    PRE_103 :      0.176
#  *    SAXS :      0.166

# %% [markdown]
# MAKING THE KEYS FOR CROSS-VALIDATION REWEIGHTING BY LEAVING ONE DATATYPE AT A TIME

# %%
new_rwt_keys = []
for i in range(len(reweighting_keys)):
    new_list = reweighting_keys.copy()
    del new_list[i]
    new_rwt_keys.append(new_list)

# %% [markdown]
# DOING A SCAN TO FIND OPTIMAL PARAMETERS FOR CROSS-VALIDATION

# %%
To_Scan = new_rwt_keys
thetas = np.linspace(0.01, 20, 20)
ref_theta = thetas[-1]
RMSE_leave_one_dict = {}
KishScan_leave_one_out = {}
for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    KishScan_leave_one_out[CS] = {}
    print('Reweight Data = {}'.format(CS))
    RMSE_leave_one_dict[CS] = {}

    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}
    compare_dict_v = {key: {} for key in compdata.keys()}

    ####### B) The reweighting procedure

    obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)
    obs_exp_v, traj_v, err_v, sigma_md_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays_with_sigma(Validation_Data, expdata, compdata, theta_0, sd, compare_dict_v)

    # THETA CYCLE
    theta_list = []
    kish_list = []
    rmsd_f_list = []
    for theta_m in np.flip(thetas):

        s = '{:.2f}'.format(theta_m)
        sigma_reg = theta_m * err_r
        sigma_md = sigma_md_r
        RMSE_leave_one_dict[CS][s] = {}

        # iv) Print dimensions
        nobs_r = len(obs_exp_r)
        nobs_v = len(obs_exp_v)
        # Print_Number_of_Data(nframes, nobs_r, nobs_v, data_r_type, data_v_type)

        # v) perform minimization
        # OBS: res.X = lagrange multiplier
        weight_bias = np.ones(nframes)

        if 'RDC' in Reweight_Data:
            initial_weights = weight_bias
            initial_weights /= np.sum(initial_weights)
            initial_obs_r = np.dot(traj_r, initial_weights)
            initial_obs_r
            exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
            calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
            qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
            qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

            if (qf_neg < qf_pos):
                c = -c_neg
            else:
                c = c_pos

            RDC_rows = np.where(data_r_type['RDC'] == 1)
            traj_r[RDC_rows] = traj_r[RDC_rows] * c

        if 'RDC' in Validation_Data:
            initial_weights = weight_bias
            initial_weights /= np.sum(initial_weights)
            initial_obs_v = np.dot(traj_v, initial_weights)
            exp_rdc = np.trim_zeros(obs_exp_v * data_v_type['RDC'])
            calc_rdc = np.trim_zeros(initial_obs_v * data_v_type['RDC'])
            qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
            qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

            if (qf_neg < qf_pos):
                c = -c_neg
            else:
                c = c_pos

            RDC_rows = np.where(data_v_type['RDC'] == 1)
            traj_v[RDC_rows] = traj_v[RDC_rows] * c

        res = sp.optimize.minimize(func_sigma_reg_sigma_md,
                                    args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                    x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
        initial_weights = Normalize_Weights(weight_bias)
        initial_obs_r = np.dot(traj_r, initial_weights)
        initial_obs_v = np.dot(traj_v, initial_weights)

        final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
        final_obs_r = np.dot(traj_r, final_weights)
        final_obs_v = np.dot(traj_v, final_weights)
        # g) calculating Kish effective size
        Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
        Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)

        Kish_ratio = (Ks_a / Ks_b) * 100
        RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
        RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

        theta_list.append(theta_m)
        kish_list.append(Kish_ratio)
        rmsd_f_list.append(RMSE_reweight)
        RMSE_r_i = {}
        RMSE_v_i = {}
        RMSE_r_f = {}
        RMSE_v_f = {}
        RMSE_r_i['Tot'] = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))

        for t in data_r_type:
            RMSE_r_i[t] = np.sqrt(
                np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                    obs_exp_r * data_r_type['RDC'])
                RMSE_r_i['RDC'] = qf

        RMSE_v_i['Tot'] = np.sqrt(
            np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
        for t in data_v_type:
            RMSE_v_i[t] = np.sqrt(
                np.sum((initial_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_v * data_v_type['RDC'],
                                                                    obs_exp_v * data_v_type['RDC'])
                RMSE_v_i['RDC'] = qf

        RMSE_r_f['Tot'] = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

        for t in data_r_type:
            RMSE_r_f[t] = np.sqrt(np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                    obs_exp_r * data_r_type['RDC'])
                RMSE_r_f['RDC'] = qf

        for t in data_v_type:
            RMSE_v_f[t] = np.sqrt(np.sum((final_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_v * data_v_type['RDC'],
                                                                    obs_exp_v * data_v_type['RDC'])
                RMSE_v_f['RDC'] = qf

        RMSE_leave_one_dict[CS][s]['Kish'] = Kish_ratio
        RMSE_leave_one_dict[CS][s]['r_i'] = RMSE_r_i
        RMSE_leave_one_dict[CS][s]['r_f'] = RMSE_r_f
        RMSE_leave_one_dict[CS][s]['v_i'] = RMSE_v_i
        RMSE_leave_one_dict[CS][s]['v_f'] = RMSE_v_f

    KishScan_leave_one_out[CS]['kish'] = np.column_stack((theta_list, kish_list))
    KishScan_leave_one_out[CS]['rmsd'] = np.column_stack((theta_list, rmsd_f_list))
# Out:
# Reweight Data = CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103

# %% [markdown]
# FINDING OPTIMAL PARAMETER VALUE FOR CROSS-VALIDATION REWEIGHTING

# %%
kish_min = 10
theta_dict_leave_one = {}
Kish_ratio_vals = []
for key in KishScan_leave_one_out:
    k = KishScan_leave_one_out[key]['kish']
    b = (np.where(k[:, 1] >= kish_min))[0]
    idx = b[-1]
    idy = b[-2]
    theta_m = k[idx][0]
    Kish_ratio_vals.append(theta_m)
    if (theta_m == 0):
        theta_m = k[idy][0]
    theta_dict_leave_one[key] = {}
    theta_dict_leave_one[key] = (theta_m)

# %% [markdown]
# CROSS-VALIDATION REWEIGHTING WITH OPTIMAL PARAMETERS

# %%
 To_Scan = new_rwt_keys

for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    print('Reweight Data = {}'.format(CS))
    CS_dir = join(leave_dir, CS)
    if not os.path.exists(CS_dir):
        os.makedirs(CS_dir)

    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}
    compare_dict_v = {key: {} for key in compdata.keys()}

    obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(
        Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)
    obs_exp_v, traj_v, err_v, sigma_md_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays_with_sigma(
        Validation_Data, expdata, compdata, theta_0, sd, compare_dict_v)

    theta_m = theta_dict_leave_one[CS]
    s = '{:.2f}'.format(theta_m)
    print(s)
    sigma_reg = theta_m * err_r
    sigma_md = sigma_md_r

    # iv) Print dimensions
    nobs_r = len(obs_exp_r)
    nobs_v = len(obs_exp_v)

    # v) perform minimization
    # OBS: res.X = lagrange multiplier
    weight_bias = np.ones(nframes)
    if 'RDC' in Reweight_Data:
        intial_weights = weight_bias
        initial_weights /= np.sum(initial_weights)
        initial_obs_r = np.dot(traj_r, initial_weights)
        initial_obs_r
        exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
        calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
        qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
        qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

        if (qf_neg < qf_pos):
            c = -c_neg
        else:
            c = c_pos
        RDC_rows = np.where(data_r_type['RDC'] == 1)
        traj_r[RDC_rows] = traj_r[RDC_rows] * c

    if 'RDC' in Validation_Data:
        intial_weights = weight_bias
        initial_weights /= np.sum(initial_weights)
        initial_obs_v = np.dot(traj_v, initial_weights)
        initial_obs_v
        exp_rdc = np.trim_zeros(obs_exp_v * data_v_type['RDC'])
        calc_rdc = np.trim_zeros(initial_obs_v * data_v_type['RDC'])
        qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
        qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

        if (qf_neg < qf_pos):
            c = -c_neg
        else:
            c = c_pos
        RDC_rows = np.where(data_v_type['RDC'] == 1)
        traj_v[RDC_rows] = traj_v[RDC_rows] * c

    res = sp.optimize.minimize(func_sigma_reg_sigma_md, args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
    initial_weights = Normalize_Weights(weight_bias)
    initial_obs_r = np.dot(traj_r, initial_weights)
    initial_obs_v = np.dot(traj_v, initial_weights)
    # if res.success: print("\nMinimization worked: {}\n".format(res.success))
    # else: raise ValueError('Minimization with {}, theta = {} as reweighting data did not worked!'.format(CS, s))
    final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
    # e) final average observables for reweighting and validation
    final_obs_r = np.dot(traj_r, final_weights)
    final_obs_v = np.dot(traj_v, final_weights)
    # g) calculating Kish effective size
    Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
    Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)
    # print("Initial Kish size : %9.6lf %d" % (Ks_b, Ks_b*nframes))
    # print("Reweighted Kish size : %9.6lf %d" % (Ks_a, Ks_a*nframes))
    Kish_ratio = (Ks_a / Ks_b) * 100
    RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
    RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

    #     plot_fitting_data(final_weights)

    print(CS, "Theta:", theta_m, "Kish: %9.6lf" % (Kish_ratio), "RMSD initail: %0.4f" % RMSE_initial,
            "RMSD final: %0.4f" % RMSE_reweight)

    print("Initial RMSE reweight data ")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))

        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])
            # print(" *    RDC scaled RMSD:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Initial RMSE validation data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_v - obs_exp_v) ** 2)))

    for t in data_v_type:
        print(" *    %2s :" % t, end='')
        # (initial_obs_v-obs_exp_v)**2*data_v_type[t])
        print("     %6.3lf" % np.sqrt(
            np.sum((initial_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_v * data_v_type['RDC'],
                                                                obs_exp_v * data_v_type['RDC'])
            # print(" *    RDC scaled RMSD:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE reweight data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdcs_scale_f, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])
            # print(" *    RDC RMSE_scale:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE validation data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_v - obs_exp_v) ** 2)))

    for t in data_v_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((final_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_f, c = scale_rdc_Q(final_obs_v * data_v_type['RDC'],
                                                                obs_exp_v * data_v_type['RDC'])
            # print(" *    RDC RMSE_scale:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)
    np.savetxt('%s/weights_final.dat' % (CS_dir), final_weights, fmt=" %6.12lf")
    # print final weights to file

    f = open("%s/weights_final.a.dat" % CS_dir, "w")
    for w in final_weights:
        f.write("%e\n" % w)
    f.close()
# Out:
# Reweight Data = CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 10.565220 RMSD initail: 1.2839 RMSD final: 1.1542
# Initial RMSE reweight data
#  * Total :      1.284
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.760
#  *    CA :      0.760
# Final RMSE reweight data
#  * Total :      1.154
#  *    CB :      1.184
#  *     H :      0.227
#  *     C :      0.571
#  *     N :      1.759
#  *    RDC :      2.965
#  *    RDC Q_scaled:  0.632
#  *    JHNHA :      0.798
#  *    JCC :      0.222
#  *    PRE_24 :      0.294
#  *    PRE_42 :      0.435
#  *    PRE_62 :      0.235
#  *    PRE_87 :      0.297
#  *    PRE_103 :      0.169
#  *    SAXS :      0.155
# Final RMSE validation data
#  * Total :      0.676
#  *    CA :      0.676
# Reweight Data = CA-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 10.329276 RMSD initail: 1.2399 RMSD final: 1.0964
# Initial RMSE reweight data
#  * Total :      1.240
#  *    CA :      0.760
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      1.264
#  *    CB :      1.264
# Final RMSE reweight data
#  * Total :      1.096
#  *    CA :      0.657
#  *     H :      0.225
#  *     C :      0.572
#  *     N :      1.736
#  *    RDC :      2.929
#  *    RDC Q_scaled:  0.622
#  *    JHNHA :      0.794
#  *    JCC :      0.226
#  *    PRE_24 :      0.297
#  *    PRE_42 :      0.433
#  *    PRE_62 :      0.234
#  *    PRE_87 :      0.295
#  *    PRE_103 :      0.170
#  *    SAXS :      0.155
# Final RMSE validation data
#  * Total :      1.197
#  *    CB :      1.197
# Reweight Data = CA-CB-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 11.788094 RMSD initail: 1.3055 RMSD final: 1.1714
# Initial RMSE reweight data
#  * Total :      1.305
#  *    CA :      0.760
#  *    CB :      1.264
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.265
#  *     H :      0.265
# Final RMSE reweight data
#  * Total :      1.171
#  *    CA :      0.665
#  *    CB :      1.188
#  *     C :      0.572
#  *     N :      1.763
#  *    RDC :      2.954
#  *    RDC Q_scaled:  0.629
#  *    JHNHA :      0.796
#  *    JCC :      0.223
#  *    PRE_24 :      0.295
#  *    PRE_42 :      0.436
#  *    PRE_62 :      0.236
#  *    PRE_87 :      0.298
#  *    PRE_103 :      0.169
#  *    SAXS :      0.155
# Final RMSE validation data
#  * Total :      0.231
#  *     H :      0.231
# Reweight Data = CA-CB-H-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 10.694391 RMSD initail: 1.2901 RMSD final: 1.1520
# Initial RMSE reweight data
#  * Total :      1.290
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.643
#  *     C :      0.643
# Final RMSE reweight data
#  * Total :      1.152
#  *    CA :      0.661
#  *    CB :      1.190
#  *     H :      0.226
#  *     N :      1.745
#  *    RDC :      2.942
#  *    RDC Q_scaled:  0.626
#  *    JHNHA :      0.794
#  *    JCC :      0.226
#  *    PRE_24 :      0.296
#  *    PRE_42 :      0.434
#  *    PRE_62 :      0.235
#  *    PRE_87 :      0.296
#  *    PRE_103 :      0.170
#  *    SAXS :      0.155
# Final RMSE validation data
#  * Total :      0.576
#  *     C :      0.576
# Reweight Data = CA-CB-H-C-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 10.074260 RMSD initail: 1.1199 RMSD final: 1.0194
# Initial RMSE reweight data
#  * Total :      1.120
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      2.041
#  *     N :      2.041
# Final RMSE reweight data
#  * Total :      1.019
#  *    CA :      0.667
#  *    CB :      1.186
#  *     H :      0.229
#  *     C :      0.572
#  *    RDC :      2.961
#  *    RDC Q_scaled:  0.630
#  *    JHNHA :      0.793
#  *    JCC :      0.224
#  *    PRE_24 :      0.294
#  *    PRE_42 :      0.435
#  *    PRE_62 :      0.235
#  *    PRE_87 :      0.296
#  *    PRE_103 :      0.168
#  *    SAXS :      0.155
# Final RMSE validation data
#  * Total :      1.798
#  *     N :      1.798
# Reweight Data = CA-CB-H-C-N-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 4.22
# CA-CB-H-C-N-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 4.218421052631578 Kish: 42.709549 RMSD initail: 0.8906 RMSD final: 0.8173
# Initial RMSE reweight data
#  * Total :      0.891
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      3.234
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
# Final RMSE reweight data
#  * Total :      0.817
#  *    CA :      0.698
#  *    CB :      1.213
#  *     H :      0.241
#  *     C :      0.598
#  *     N :      1.847
#  *    JHNHA :      0.851
#  *    JCC :      0.239
#  *    PRE_24 :      0.307
#  *    PRE_42 :      0.459
#  *    PRE_62 :      0.259
#  *    PRE_87 :      0.315
#  *    PRE_103 :      0.174
#  *    SAXS :      0.167
# Final RMSE validation data
#  * Total :      3.102
#  *    RDC :      3.102
#  *    RDC Q_scaled:  0.675
# Reweight Data = CA-CB-H-C-N-RDC-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 4.22
# CA-CB-H-C-N-RDC-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 4.218421052631578 Kish: 43.057435 RMSD initail: 1.2538 RMSD final: 1.1654
# Initial RMSE reweight data
#  * Total :      1.254
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.953
#  *    JHNHA :      0.953
# Final RMSE reweight data
#  * Total :      1.165
#  *    CA :      0.696
#  *    CB :      1.218
#  *     H :      0.241
#  *     C :      0.599
#  *     N :      1.841
#  *    RDC :      3.038
#  *    RDC Q_scaled:  0.659
#  *    JCC :      0.240
#  *    PRE_24 :      0.308
#  *    PRE_42 :      0.459
#  *    PRE_62 :      0.260
#  *    PRE_87 :      0.315
#  *    PRE_103 :      0.175
#  *    SAXS :      0.167
# Final RMSE validation data
#  * Total :      0.868
#  *    JHNHA :      0.868
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 4.22
# CA-CB-H-C-N-RDC-JHNHA-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 4.218421052631578 Kish: 41.785636 RMSD initail: 1.2736 RMSD final: 1.1824
# Initial RMSE reweight data
#  * Total :      1.274
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.273
#  *    JCC :      0.273
# Final RMSE reweight data
#  * Total :      1.182
#  *    CA :      0.693
#  *    CB :      1.221
#  *     H :      0.240
#  *     C :      0.601
#  *     N :      1.840
#  *    RDC :      3.036
#  *    RDC Q_scaled:  0.659
#  *    JHNHA :      0.854
#  *    PRE_24 :      0.309
#  *    PRE_42 :      0.459
#  *    PRE_62 :      0.260
#  *    PRE_87 :      0.314
#  *    PRE_103 :      0.175
#  *    SAXS :      0.167
# Final RMSE validation data
#  * Total :      0.247
#  *    JCC :      0.247
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 10.910541 RMSD initail: 1.2817 RMSD final: 1.1292
# Initial RMSE reweight data
#  * Total :      1.282
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.323
#  *    PRE_24 :      0.323
# Final RMSE reweight data
#  * Total :      1.129
#  *    CA :      0.649
#  *    CB :      1.184
#  *     H :      0.222
#  *     C :      0.566
#  *     N :      1.710
#  *    RDC :      2.910
#  *    RDC Q_scaled:  0.612
#  *    JHNHA :      0.778
#  *    JCC :      0.221
#  *    PRE_42 :      0.428
#  *    PRE_62 :      0.230
#  *    PRE_87 :      0.296
#  *    PRE_103 :      0.173
#  *    SAXS :      0.156
# Final RMSE validation data
#  * Total :      0.328
#  *    PRE_24 :      0.328
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 11.003665 RMSD initail: 1.2782 RMSD final: 1.1405
# Initial RMSE reweight data
#  * Total :      1.278
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.501
#  *    PRE_42 :      0.501
# Final RMSE reweight data
#  * Total :      1.140
#  *    CA :      0.660
#  *    CB :      1.185
#  *     H :      0.226
#  *     C :      0.570
#  *     N :      1.740
#  *    RDC :      2.945
#  *    RDC Q_scaled:  0.625
#  *    JHNHA :      0.791
#  *    JCC :      0.223
#  *    PRE_24 :      0.296
#  *    PRE_62 :      0.234
#  *    PRE_87 :      0.298
#  *    PRE_103 :      0.170
#  *    SAXS :      0.156
# Final RMSE validation data
#  * Total :      0.438
#  *    PRE_42 :      0.438
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 13.858785 RMSD initail: 1.2816 RMSD final: 1.1509
# Initial RMSE reweight data
#  * Total :      1.282
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.299
#  *    PRE_62 :      0.299
# Final RMSE reweight data
#  * Total :      1.151
#  *    CA :      0.668
#  *    CB :      1.193
#  *     H :      0.230
#  *     C :      0.577
#  *     N :      1.762
#  *    RDC :      2.952
#  *    RDC Q_scaled:  0.631
#  *    JHNHA :      0.803
#  *    JCC :      0.225
#  *    PRE_24 :      0.297
#  *    PRE_42 :      0.441
#  *    PRE_87 :      0.300
#  *    PRE_103 :      0.167
#  *    SAXS :      0.157
# Final RMSE validation data
#  * Total :      0.249
#  *    PRE_62 :      0.249
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 11.309358 RMSD initail: 1.2801 RMSD final: 1.1416
# Initial RMSE reweight data
#  * Total :      1.280
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_103 :      0.186
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.333
#  *    PRE_87 :      0.333
# Final RMSE reweight data
#  * Total :      1.142
#  *    CA :      0.660
#  *    CB :      1.184
#  *     H :      0.226
#  *     C :      0.569
#  *     N :      1.737
#  *    RDC :      2.946
#  *    RDC Q_scaled:  0.625
#  *    JHNHA :      0.790
#  *    JCC :      0.221
#  *    PRE_24 :      0.297
#  *    PRE_42 :      0.436
#  *    PRE_62 :      0.233
#  *    PRE_103 :      0.171
#  *    SAXS :      0.156
# Final RMSE validation data
#  * Total :      0.302
#  *    PRE_87 :      0.302
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-SAXS
# 4.22
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-SAXS Theta: 4.218421052631578 Kish: 39.164180 RMSD initail: 1.2821 RMSD final: 1.1620
# Initial RMSE reweight data
#  * Total :      1.282
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    SAXS :      0.180
# Initial RMSE validation data
#  * Total :      0.186
#  *    PRE_103 :      0.186
# Final RMSE reweight data
#  * Total :      1.162
#  *    CA :      0.670
#  *    CB :      1.198
#  *     H :      0.232
#  *     C :      0.587
#  *     N :      1.760
#  *    RDC :      2.992
#  *    RDC Q_scaled:  0.638
#  *    JHNHA :      0.828
#  *    JCC :      0.237
#  *    PRE_24 :      0.315
#  *    PRE_42 :      0.448
#  *    PRE_62 :      0.241
#  *    PRE_87 :      0.310
#  *    SAXS :      0.173
# Final RMSE validation data
#  * Total :      0.221
#  *    PRE_103 :      0.221
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103 Theta: 3.1663157894736838 Kish: 11.522380 RMSD initail: 1.2596 RMSD final: 1.1226
# Initial RMSE reweight data
#  * Total :      1.260
#  *    CA :      0.760
#  *    CB :      1.264
#  *     H :      0.265
#  *     C :      0.643
#  *     N :      2.041
#  *    RDC :      3.234
#  *    RDC scaled Q:  0.711
#  *    JHNHA :      0.953
#  *    JCC :      0.273
#  *    PRE_24 :      0.323
#  *    PRE_42 :      0.501
#  *    PRE_62 :      0.299
#  *    PRE_87 :      0.333
#  *    PRE_103 :      0.186
# Initial RMSE validation data
#  * Total :      0.180
#  *    SAXS :      0.180
# Final RMSE reweight data
#  * Total :      1.123
#  *    CA :      0.659
#  *    CB :      1.184
#  *     H :      0.225
#  *     C :      0.569
#  *     N :      1.733
#  *    RDC :      2.947
#  *    RDC Q_scaled:  0.624
#  *    JHNHA :      0.788
#  *    JCC :      0.222
#  *    PRE_24 :      0.298
#  *    PRE_42 :      0.435
#  *    PRE_62 :      0.233
#  *    PRE_87 :      0.297
#  *    PRE_103 :      0.173
# Final RMSE validation data
#  * Total :      0.157
#  *    SAXS :      0.157

# %% [markdown]
# SAVING ALL THE INFORMATION FROM THE OPTIMIZED REWEIGHTING ROUNDS AS DICTIONARIES TO LOAD FOR MAKING THE ANALYSIS PLOTS

# %%
import pickle

with open('%s/RMSE_single.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(RMSE_dict, fp)

with open('%s/RMSE_leave_one.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(RMSE_leave_one_dict, fp)

with open('%s/RMSE_combined.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(RMSE_dict_combined, fp)

with open('%s/theta_dict.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(theta_dict, fp)

with open('%s/theta_dict_combined.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(theta_dict_combined, fp)

with open('%s/theta_dict_leave_one.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(theta_dict_leave_one, fp)

with open('%s/KishScan_single_data.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(KishScan_one_data, fp)

with open('%s/KishScan_leave_one.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(KishScan_leave_one_out, fp)

with open('%s/KishScan_combined.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(KishScan_combined, fp)

with open('%s/colors.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(colors, fp)
