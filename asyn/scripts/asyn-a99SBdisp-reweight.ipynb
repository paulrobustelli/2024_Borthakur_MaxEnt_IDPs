# %%
from reweight_functions import *
import pickle

# %% [markdown]
# SETTING THE DIRECTORIES TO THE EXPERIMENTAL, COMPUTED DATA AND MAKING DIRECTORIES FOR THE OUTPUT AND FOR SAVING THE REWEIGHTED RMSES AS DICTIONARIES IN THEIR OWN DIRECTORIES

# %%
main_path = '/Users/kaushikb/Desktop/Paper_Repo/asyn/'

outdir = os.path.join(main_path, 'a99SBdisp', 'reweight_trial')
datadir = os.path.join(main_path, 'a99SBdisp', 'Average_Data')
expdatadir = os.path.join(main_path, 'Exp_Data')
weights_dir = os.path.join(outdir, 'weights')

if not os.path.exists(outdir):
    os.makedirs(outdir)
if not os.path.exists(weights_dir):
    os.makedirs(weights_dir)

single_dir = os.path.join(weights_dir + "/single_data")
if not os.path.exists(single_dir):
    os.makedirs(single_dir)
leave_dir = os.path.join(weights_dir + "/leave_one_data")
if not os.path.exists(leave_dir):
    os.makedirs(leave_dir)
combined_dir = os.path.join(weights_dir + "/combined_data")
if not os.path.exists(combined_dir):
    os.makedirs(combined_dir)

dic_dir = os.path.join(outdir, 'dictionaries')
if not os.path.exists(dic_dir):
    os.makedirs(dic_dir)

# %% [markdown]
# SETTING THE REWEIGHTING KEYS (DATA TYPES TO USE IN THE REWEIGHTING PROCEDURE)

# %%
colors = {'C': 'royalblue','HA': 'orange', 'CA': 'red',  'CB': 'forestgreen', 'H': 'mediumorchid', 'N': 'darkslateblue', 'JHNHA': 'cornflowerblue', 
'JCC': 'pink', 'Rg': 'grey', 'RDC': 'firebrick', 'RDC_Q': 'firebrick', 'SAXS':'teal', 'PRE_18': 'mediumslateblue', 'PRE_24':'mediumpurple',
 'PRE_42': 'rebeccapurple', 'PRE_62': 'fuchsia',
 'PRE_87':'darkviolet',
 'PRE_103': 'plum',
 'Tot': 'black'}

chemical_shifts = ['CB', 'HA', 'CA', 'H', 'N', 'C']
theta_0 = {'HA': 1., 'CA': 1, 'CB': 1., 'C': 1., 'H': 1., 'HA2': 1., 'HA3': 1., 'N': 1.,
               'RDC': 1., 'Rg': 1., 'JHNHA': 1., 'JCC': 1., 'SAXS': 1.,
               'PRE_24': 1., 'PRE_42': 1., 'PRE_62': 1., 'PRE_87': 1.,
                'PRE_103': 1.}

to_remove = ['HA', 'HA2', 'HA3']
reweighting_keys = ['CA', 'CB', 'H', 'C', 'N', 'RDC', 'JHNHA', 'JCC',
                    'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87',
                    'PRE_103', 'SAXS']

print('Main settings:\n')
print('Reweighting keys: {}'.format(reweighting_keys))
# Out:
# Main settings:
#
# Reweighting keys: ['CA', 'CB', 'H', 'C', 'N', 'RDC', 'JHNHA', 'JCC', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103', 'SAXS']

# %% [markdown]
# LOADING THE EXPERIMENTAL AND COMPUTED DATA

# %%
# chemical shifts
expdata = read_exp_cs(join(expdatadir, 'CS.exp.dat'))
compdata = read_cs_md(join(datadir, 'chemical_shifts.all.csv'), )
# RDC
expdata = add_exp_data(join(expdatadir, 'RDC.exp.dat'), expdata, 'RDC')
compdata = add_md_data(join(datadir, 'RDC.all.csv'), compdata, 'RDC')

# J_couplings
expdata = add_exp_data(expdatadir + '/JHNHA.exp.dat', expdata, 'JHNHA')
compdata = add_md_data(datadir + '/J_HNHA1.all.csv', compdata, 'JHNHA')

expdata = add_exp_data(expdatadir + '/JCC.exp.dat', expdata, 'JCC')
compdata = add_md_data(datadir + '/J_CC.all.csv', compdata, 'JCC')

# SAXS
expdata = add_exp_data(expdatadir + '/SAXS.exp.dat', expdata, 'SAXS')
compdata = add_md_data(datadir + '/SAXS.csv', compdata, 'SAXS')

# PREs

expdata = add_exp_data(expdatadir + '/Iratio-label-24.exp.dat', expdata, 'PRE_24')
compdata = add_md_data(datadir + '/Iratio-label-24.all.csv', compdata, 'PRE_24')

expdata = add_exp_data(expdatadir + '/Iratio-label-42.exp.dat', expdata, 'PRE_42')
compdata = add_md_data(datadir + '/Iratio-label-42.all.csv', compdata, 'PRE_42')

expdata = add_exp_data(expdatadir + '/Iratio-label-62.exp.dat', expdata, 'PRE_62')
compdata = add_md_data(datadir + '/Iratio-label-62.all.csv', compdata, 'PRE_62')

expdata = add_exp_data(expdatadir + '/Iratio-label-87.exp.dat', expdata, 'PRE_87')
compdata = add_md_data(datadir + '/Iratio-label-87.all.csv', compdata, 'PRE_87')

expdata = add_exp_data(expdatadir + '/Iratio-label-103.exp.dat', expdata, 'PRE_103')
compdata = add_md_data(datadir + '/Iratio-label-103.all.csv', compdata, 'PRE_103')

# Elimination of compdata that are not in expdata and viceversa
compdata, expdata = Align_Comp_Exp_Data(compdata, expdata)

####### TRAJ-related quantities

nframes = len(compdata[list(compdata.keys())[1]][list(compdata[list(compdata.keys())[1]].keys())[0]])

# labels
exp_labels = list(compdata.keys())
true_exp_labels = [key for key in exp_labels if key not in to_remove]

print(
    'Correctely acquired data from experiments and for MD simulations for the following quantities:\n{}\nNumber of frames = {}'.format(
        [str(key) for key in compdata.keys()], nframes))
# Out:
# Correctely acquired data from experiments and for MD simulations for the following quantities:
# ['HA', 'CA', 'CB', 'C', 'H', 'HA2', 'HA3', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# Number of frames = 29976

# %% [markdown]
# SETTING ALL THE DATA INTO DICTIONARIES AND ALIGNING THE DATA TO MATCH AND CALCULATING THE SIGMA MD

# %%
keys_list = []
for keys in expdata['SAXS'].keys():
    keys_list.append(keys)

first_key_value = expdata['SAXS']['0.0097']

for i in keys_list:
    expdata['SAXS'][i] = np.array(expdata['SAXS'][i]) / first_key_value

first_key_series = compdata['SAXS']['0.0097']

for i in keys_list:
    compdata['SAXS'][i] = (compdata['SAXS'][i]) / first_key_series

# %%
sd = {}
To_Scan = reweighting_keys
for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    print('Reweight Data = {}'.format(CS))
    print('Validation Data = {}'.format(Validation_Data))

    ### debugging variables
    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}
    compare_dict_v = {key: {} for key in compdata.keys()}

    ####### B) The reweighting procedure

    # i) Process Reweight data into arrays 
    obs_exp_r, traj_r, err_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays(Reweight_Data,
                                                                                                expdata, compdata,
                                                                                                theta_0,
                                                                                                compare_dict_r)

    # ii) Process Validation data into arrays 
    obs_exp_v, traj_v, err_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays(Validation_Data,
                                                                                                expdata, compdata,
                                                                                                theta_0,
                                                                                                compare_dict_v)

    # final_weights

    for key in data_v_type:
        print(key)
        res = []
        md_ave = []
        sigmas = []
        exp = []
        sd[key] = {}
        for key2 in compare_dict_v[key]:
            timeseries = compare_dict_v[key][key2][1]
            uniform_weights = np.ones(len(timeseries))
            dim = 5000
            A, W = Weighted_Independent_Blocks(timeseries, uniform_weights, dim, verbose=False)
            ave = np.average(A, weights=W)
            sigma = Weighted_Sigma_of_Mean(A, W)
            sd[key][key2] = np.array([float(key2), float(compare_dict_v[key][key2][0]), float(ave), float(sigma)])

    for key in data_r_type:
        print(key)
        res = []
        md_ave = []
        sigmas = []
        exp = []
        sd[key] = {}
        for key2 in compare_dict_r[key]:
            timeseries = compare_dict_r[key][key2][1]
            uniform_weights = np.ones(len(timeseries))
            dim = 5000
            A, W = Weighted_Independent_Blocks(timeseries, uniform_weights, dim, verbose=False)
            ave = np.average(A, weights=W)
            sigma = Weighted_Sigma_of_Mean(A, W)
            sd[key][key2] = np.array([float(key2), float(compare_dict_r[key][key2][0]), float(ave), float(sigma)])
# Out:
# Reweight Data = CA
# Validation Data = ['CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# CA
# Reweight Data = CB
# Validation Data = ['CA', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# CB
# Reweight Data = H
# Validation Data = ['CA', 'CB', 'C', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# H
# Reweight Data = C
# Validation Data = ['CA', 'CB', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# C
# Reweight Data = N
# Validation Data = ['CA', 'CB', 'C', 'H', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# N
# Reweight Data = RDC
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# RDC
# Reweight Data = JHNHA
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# JHNHA
# Reweight Data = JCC
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# JCC
# Reweight Data = PRE_24
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# PRE_24
# Reweight Data = PRE_42
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_62
# PRE_87
# PRE_103
# PRE_42
# Reweight Data = PRE_62
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_87
# PRE_103
# PRE_62
# Reweight Data = PRE_87
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_103
# PRE_87
# Reweight Data = PRE_103
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'SAXS', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# SAXS
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# Reweight Data = SAXS
# Validation Data = ['CA', 'CB', 'C', 'H', 'N', 'RDC', 'JHNHA', 'JCC', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
# CA
# CB
# C
# H
# N
# RDC
# JHNHA
# JCC
# PRE_24
# PRE_42
# PRE_62
# PRE_87
# PRE_103
# SAXS

# %% [markdown]
# INITIAL ROUND OF REWEIGHTING FOR A RANGE OF SIGMA_REG VALUES FOR EACH INDIVIDUAL DATA TYPE

# %%
To_Scan = reweighting_keys
thetas = np.linspace(0.001, 20, 200)
ref_theta = thetas[-1]
RMSE_dict = {}
KishScan_one_data = {}


for CS in To_Scan:
        CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
        KishScan_one_data[CS] = {}
        print('Reweight Data = {}'.format(CS))
        RMSE_dict[CS] = {}

        ### debugging variables
        compare = []
        compare_dict_r = {key: {} for key in compdata.keys()}
        compare_dict_v = {key: {} for key in compdata.keys()}

        ####### B) The reweighting procedure

        obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(
            Reweight_Data, expdata, compdata, theta_0, sd, compare_dict_r)
        obs_exp_v, traj_v, err_v, sigma_md_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays_with_sigma(
            Validation_Data, expdata, compdata, theta_0, sd, compare_dict_v)

        # THETA CYCLE
        theta_list = []
        kish_list = []
        rmsd_f_list = []
        for theta_m in np.flip(thetas):

            s = '{:.2f}'.format(theta_m)
            # print(s)
            sigma_reg = theta_m * err_r
            sigma_md = sigma_md_r
            RMSE_dict[CS][s] = {}

            # iv) Print dimensions
            nobs_r = len(obs_exp_r)
            nobs_v = len(obs_exp_v)
            # Print_Number_of_Data(nframes, nobs_r, nobs_v, data_r_type, data_v_type)

            # v) perform minimization
            # OBS: res.X = lagrange multiplier
            weight_bias = np.ones(nframes)

            if 'RDC' in Reweight_Data:
                initial_weights = weight_bias
                initial_weights /= np.sum(initial_weights)
                initial_obs_r = np.dot(traj_r, initial_weights)
                initial_obs_r
                exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
                calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
                qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
                qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

                if (qf_neg < qf_pos):
                    c = -c_neg
                else:
                    c = c_pos

                RDC_rows = np.where(data_r_type['RDC'] == 1)
                traj_r[RDC_rows] = traj_r[RDC_rows] * c

            if 'RDC' in Validation_Data:
                initial_weights = weight_bias
                initial_weights /= np.sum(initial_weights)
                initial_obs_v = np.dot(traj_v, initial_weights)
                exp_rdc = np.trim_zeros(obs_exp_v * data_v_type['RDC'])
                calc_rdc = np.trim_zeros(initial_obs_v * data_v_type['RDC'])
                qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
                qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

                if (qf_neg < qf_pos):
                    c = -c_neg
                else:
                    c = c_pos

                RDC_rows = np.where(data_v_type['RDC'] == 1)
                traj_v[RDC_rows] = traj_v[RDC_rows] * c

            res = sp.optimize.minimize(func_sigma_reg_sigma_md,
                                       args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                       x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
            initial_weights = Normalize_Weights(weight_bias)
            initial_obs_r = np.dot(traj_r, initial_weights)
            initial_obs_v = np.dot(traj_v, initial_weights)

            final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
            final_obs_r = np.dot(traj_r, final_weights)
            final_obs_v = np.dot(traj_v, final_weights)
            # g) calculating Kish effective size
            Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
            Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)

            Kish_ratio = (Ks_a / Ks_b) * 100
            RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
            RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

            theta_list.append(theta_m)
            kish_list.append(Kish_ratio)
            rmsd_f_list.append(RMSE_reweight)
            RMSE_r_i = {}
            RMSE_v_i = {}
            RMSE_r_f = {}
            RMSE_v_f = {}
            RMSE_r_i['Tot'] = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))

            for t in data_r_type:
                RMSE_r_i[t] = np.sqrt(
                    np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
                if str(t) == 'RDC':
                    qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                       obs_exp_r * data_r_type['RDC'])
                    RMSE_r_i['RDC'] = qf

            RMSE_v_i['Tot'] = np.sqrt(
                np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            for t in data_v_type:
                RMSE_v_i[t] = np.sqrt(
                    np.sum((initial_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t]))
                if str(t) == 'RDC':
                    qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_v * data_v_type['RDC'],
                                                                       obs_exp_v * data_v_type['RDC'])
                    RMSE_v_i['RDC'] = qf

            RMSE_r_f['Tot'] = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

            for t in data_r_type:
                RMSE_r_f[t] = np.sqrt(np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
                if str(t) == 'RDC':
                    qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                       obs_exp_r * data_r_type['RDC'])
                    RMSE_r_f['RDC'] = qf

            for t in data_v_type:
                RMSE_v_f[t] = np.sqrt(np.sum((final_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t]))
                if str(t) == 'RDC':
                    qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_v * data_v_type['RDC'],
                                                                       obs_exp_v * data_v_type['RDC'])
                    RMSE_v_f['RDC'] = qf

            RMSE_dict[CS][s]['Kish'] = Kish_ratio
            RMSE_dict[CS][s]['r_i'] = RMSE_r_i
            RMSE_dict[CS][s]['r_f'] = RMSE_r_f
            RMSE_dict[CS][s]['v_i'] = RMSE_v_i
            RMSE_dict[CS][s]['v_f'] = RMSE_v_f

        KishScan_one_data[CS]['kish'] = np.column_stack((theta_list, kish_list))
        KishScan_one_data[CS]['rmsd'] = np.column_stack((theta_list, rmsd_f_list))
# Out:
# Reweight Data = CA
# Reweight Data = CB
# Reweight Data = H
# Reweight Data = C
# Reweight Data = N
# Reweight Data = RDC
# Reweight Data = JHNHA
# Reweight Data = JCC
# Reweight Data = PRE_24
# Reweight Data = PRE_42
# Reweight Data = PRE_62
# Reweight Data = PRE_87
# Reweight Data = PRE_103
# Reweight Data = SAXS

# %% [markdown]
# FINDING OUT THE OPTIMAL VALUE OF SIGMA_REG FOR EACH DATA TYPE BASED ON DESIRED ENSEMBLE SIZE (KISH=10/ KISH RATIO = 0.1)

# %%
kish_min = 10
theta_dict = {}
Kish_ratio_vals = []
for key in KishScan_one_data:
    k = KishScan_one_data[key]['kish']
    b = (np.where(k[:, 1] >= kish_min))[0]
    idx = b[-1]
    idy = b[-2]
    theta_m = k[idx][0]
    Kish_ratio_vals.append(theta_m)
    if (theta_m == 0):
        theta_m = k[idy][0]
    theta_dict[key] = {}
    theta_dict[key] = (theta_m)

# %%
def print_results():
    print(CS, "Theta:", theta_m, "Kish: %9.6lf" % (Kish_ratio), "RMSD initail: %0.4f" % RMSE_initial,
            "RMSD final: %0.4f" % RMSE_reweight)

    print("Initial RMSE reweight data ")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))

        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])

            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Initial RMSE validation data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_v - obs_exp_v) ** 2)))

    for t in data_v_type:
        print(" *    %2s :" % t, end='')
  
        print("     %6.3lf" % np.sqrt(
            np.sum((initial_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_v * data_v_type['RDC'],
                                                                obs_exp_v * data_v_type['RDC'])
 
            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE reweight data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdcs_scale_f, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])

            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE validation data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_v - obs_exp_v) ** 2)))

    for t in data_v_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((final_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_f, c = scale_rdc_Q(final_obs_v * data_v_type['RDC'],
                                                                obs_exp_v * data_v_type['RDC'])
           
            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)

# %% [markdown]
# SECOND ROUND OF REWEIGHTING BASED ON OPTIMAL VALUES OF THE PARAMETERS

# %%
To_Scan = reweighting_keys

for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    print('Reweight Data = {}'.format(CS))
    CS_dir = join(single_dir, CS)
    if not os.path.exists(CS_dir):
        os.makedirs(CS_dir)

    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}
    compare_dict_v = {key: {} for key in compdata.keys()}

    obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(
        Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)
    obs_exp_v, traj_v, err_v, sigma_md_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays_with_sigma(
        Validation_Data, expdata, compdata, theta_0, sd, compare_dict_v)

    theta_m = theta_dict[CS]
    s = '{:.2f}'.format(theta_m)
    print(s)
    sigma_reg = theta_m
    sigma_md = sigma_md_r

    # iv) Print dimensions
    nobs_r = len(obs_exp_r)
    nobs_v = len(obs_exp_v)

    # v) perform minimization
    # OBS: res.X = lagrange multiplier
    weight_bias = np.ones(nframes)
    if 'RDC' in Reweight_Data:
        intial_weights = weight_bias
        initial_weights /= np.sum(initial_weights)
        initial_obs_r = np.dot(traj_r, initial_weights)
        initial_obs_r
        exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
        calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
        qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
        qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

        if (qf_neg < qf_pos):
            c = -c_neg
        else:
            c = c_pos
        RDC_rows = np.where(data_r_type['RDC'] == 1)
        traj_r[RDC_rows] = traj_r[RDC_rows] * c

    if 'RDC' in Validation_Data:
        intial_weights = weight_bias
        initial_weights /= np.sum(initial_weights)
        initial_obs_v = np.dot(traj_v, initial_weights)
        initial_obs_v
        exp_rdc = np.trim_zeros(obs_exp_v * data_v_type['RDC'])
        calc_rdc = np.trim_zeros(initial_obs_v * data_v_type['RDC'])
        qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
        qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

        if (qf_neg < qf_pos):
            c = -c_neg
        else:
            c = c_pos
        RDC_rows = np.where(data_v_type['RDC'] == 1)
        traj_v[RDC_rows] = traj_v[RDC_rows] * c

    res = sp.optimize.minimize(func_sigma_reg_sigma_md, args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
    initial_weights = Normalize_Weights(weight_bias)
    initial_obs_r = np.dot(traj_r, initial_weights)
    initial_obs_v = np.dot(traj_v, initial_weights)
    final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
    # e) final average observables for reweighting and validation
    final_obs_r = np.dot(traj_r, final_weights)
    final_obs_v = np.dot(traj_v, final_weights)
    # g) calculating Kish effective size
    Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
    Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)
    Kish_ratio = (Ks_a / Ks_b) * 100
    RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
    RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))
    print_results()

    np.savetxt('%s/weights_final.dat' % (CS_dir), final_weights, fmt=" %6.12lf")
    # print final weights to file

    f = open("%s/weights_final.a.dat" % CS_dir, "w")
    for w in final_weights:
        f.write("%e\n" % w)
    f.close()
# Out:
# Reweight Data = CA
# 1.61
# CA Theta: 1.6089597989949747 Kish: 12.737685 RMSD initail: 0.5063 RMSD final: 0.3372
# Initial RMSE reweight data
#  * Total :      0.506
#  *    CA :      0.506
# Initial RMSE validation data
#  * Total :      0.842
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.337
#  *    CA :      0.337
# Final RMSE validation data
#  * Total :      0.785
#  *    CB :      1.115
#  *     C :      0.348
#  *     H :      0.122
#  *     N :      1.344
#  *    RDC :      1.655
#  *    RDC Q_scaled:  0.350
#  *    JHNHA :      0.913
#  *    JCC :      0.191
#  *    SAXS :      0.014
#  *    PRE_24 :      0.105
#  *    PRE_42 :      0.112
#  *    PRE_62 :      0.113
#  *    PRE_87 :      0.163
#  *    PRE_103 :      0.158
# Reweight Data = CB
# 2.51
# CB Theta: 2.513437185929648 Kish: 10.414048 RMSD initail: 1.0425 RMSD final: 0.8525
# Initial RMSE reweight data
#  * Total :      1.043
#  *    CB :      1.043
# Initial RMSE validation data
#  * Total :      0.791
#  *    CA :      0.506
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.853
#  *    CB :      0.853
# Final RMSE validation data
#  * Total :      0.842
#  *    CA :      0.605
#  *     C :      0.286
#  *     H :      0.155
#  *     N :      1.511
#  *    RDC :      1.953
#  *    RDC Q_scaled:  0.413
#  *    JHNHA :      1.280
#  *    JCC :      0.136
#  *    SAXS :      0.013
#  *    PRE_24 :      0.099
#  *    PRE_42 :      0.100
#  *    PRE_62 :      0.102
#  *    PRE_87 :      0.104
#  *    PRE_103 :      0.146
# Reweight Data = H
# 0.50
# H Theta: 0.5034874371859296 Kish: 20.128144 RMSD initail: 0.1356 RMSD final: 0.0972
# Initial RMSE reweight data
#  * Total :      0.136
#  *     H :      0.136
# Initial RMSE validation data
#  * Total :      0.858
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.097
#  *     H :      0.097
# Final RMSE validation data
#  * Total :      0.803
#  *    CA :      0.450
#  *    CB :      1.086
#  *     C :      0.328
#  *     N :      1.305
#  *    RDC :      1.700
#  *    RDC Q_scaled:  0.370
#  *    JHNHA :      1.048
#  *    JCC :      0.187
#  *    SAXS :      0.014
#  *    PRE_24 :      0.102
#  *    PRE_42 :      0.108
#  *    PRE_62 :      0.105
#  *    PRE_87 :      0.160
#  *    PRE_103 :      0.154
# Reweight Data = C
# 1.11
# C Theta: 1.106472361809045 Kish: 13.450708 RMSD initail: 0.3138 RMSD final: 0.2072
# Initial RMSE reweight data
#  * Total :      0.314
#  *     C :      0.314
# Initial RMSE validation data
#  * Total :      0.852
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.207
#  *     C :      0.207
# Final RMSE validation data
#  * Total :      0.825
#  *    CA :      0.538
#  *    CB :      0.984
#  *     H :      0.141
#  *     N :      1.433
#  *    RDC :      1.724
#  *    RDC Q_scaled:  0.376
#  *    JHNHA :      1.164
#  *    JCC :      0.147
#  *    SAXS :      0.015
#  *    PRE_24 :      0.100
#  *    PRE_42 :      0.108
#  *    PRE_62 :      0.101
#  *    PRE_87 :      0.125
#  *    PRE_103 :      0.154
# Reweight Data = N
# 4.72
# N Theta: 4.724381909547739 Kish: 10.636266 RMSD initail: 1.4575 RMSD final: 0.9851
# Initial RMSE reweight data
#  * Total :      1.457
#  *     N :      1.457
# Initial RMSE validation data
#  * Total :      0.709
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.985
#  *     N :      0.985
# Final RMSE validation data
#  * Total :      0.659
#  *    CA :      0.441
#  *    CB :      1.043
#  *     C :      0.320
#  *     H :      0.118
#  *    RDC :      1.637
#  *    RDC Q_scaled:  0.355
#  *    JHNHA :      1.109
#  *    JCC :      0.163
#  *    SAXS :      0.018
#  *    PRE_24 :      0.100
#  *    PRE_42 :      0.115
#  *    PRE_62 :      0.104
#  *    PRE_87 :      0.136
#  *    PRE_103 :      0.151
# Reweight Data = RDC
# 4.93
# RDC Theta: 4.925376884422111 Kish: 10.051838 RMSD initail: 1.8351 RMSD final: 0.5222
# Initial RMSE reweight data
#  * Total :      1.835
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
# Initial RMSE validation data
#  * Total :      0.660
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.522
#  *    RDC :      0.522
#  *    RDC Q_scaled:  0.111
# Final RMSE validation data
#  * Total :      0.637
#  *    CA :      0.472
#  *    CB :      1.029
#  *     C :      0.307
#  *     H :      0.132
#  *     N :      1.391
#  *    JHNHA :      1.098
#  *    JCC :      0.171
#  *    SAXS :      0.013
#  *    PRE_24 :      0.104
#  *    PRE_42 :      0.105
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.129
#  *    PRE_103 :      0.146
# Reweight Data = JHNHA
# 2.81
# JHNHA Theta: 2.814929648241206 Kish: 11.629798 RMSD initail: 1.1105 RMSD final: 0.6336
# Initial RMSE reweight data
#  * Total :      1.111
#  *    JHNHA :      1.111
# Initial RMSE validation data
#  * Total :      0.798
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.634
#  *    JHNHA :      0.634
# Final RMSE validation data
#  * Total :      0.786
#  *    CA :      0.438
#  *    CB :      1.088
#  *     C :      0.336
#  *     H :      0.130
#  *     N :      1.454
#  *    RDC :      1.763
#  *    RDC Q_scaled:  0.385
#  *    JCC :      0.202
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.110
#  *    PRE_62 :      0.105
#  *    PRE_87 :      0.160
#  *    PRE_103 :      0.149
# Reweight Data = JCC
# 0.30
# JCC Theta: 0.3024924623115578 Kish: 10.578966 RMSD initail: 0.1823 RMSD final: 0.0335
# Initial RMSE reweight data
#  * Total :      0.182
#  *    JCC :      0.182
# Initial RMSE validation data
#  * Total :      0.836
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.033
#  *    JCC :      0.033
# Final RMSE validation data
#  * Total :      0.809
#  *    CA :      0.516
#  *    CB :      0.976
#  *     C :      0.286
#  *     H :      0.141
#  *     N :      1.431
#  *    RDC :      1.731
#  *    RDC Q_scaled:  0.377
#  *    JHNHA :      1.188
#  *    SAXS :      0.014
#  *    PRE_24 :      0.107
#  *    PRE_42 :      0.095
#  *    PRE_62 :      0.101
#  *    PRE_87 :      0.107
#  *    PRE_103 :      0.148
# Reweight Data = PRE_24
# 0.30
# PRE_24 Theta: 0.3024924623115578 Kish: 20.513736 RMSD initail: 0.1063 RMSD final: 0.0571
# Initial RMSE reweight data
#  * Total :      0.106
#  *    PRE_24 :      0.106
# Initial RMSE validation data
#  * Total :      0.843
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.057
#  *    PRE_24 :      0.057
# Final RMSE validation data
#  * Total :      0.841
#  *    CA :      0.516
#  *    CB :      1.028
#  *     C :      0.316
#  *     H :      0.137
#  *     N :      1.427
#  *    RDC :      1.858
#  *    RDC Q_scaled:  0.408
#  *    JHNHA :      1.119
#  *    JCC :      0.183
#  *    SAXS :      0.016
#  *    PRE_42 :      0.122
#  *    PRE_62 :      0.109
#  *    PRE_87 :      0.144
#  *    PRE_103 :      0.145
# Reweight Data = PRE_42
# 0.20
# PRE_42 Theta: 0.20199497487437185 Kish: 15.987638 RMSD initail: 0.1074 RMSD final: 0.0539
# Initial RMSE reweight data
#  * Total :      0.107
#  *    PRE_42 :      0.107
# Initial RMSE validation data
#  * Total :      0.842
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.054
#  *    PRE_42 :      0.054
# Final RMSE validation data
#  * Total :      0.840
#  *    CA :      0.507
#  *    CB :      1.023
#  *     C :      0.315
#  *     H :      0.138
#  *     N :      1.482
#  *    RDC :      1.812
#  *    RDC Q_scaled:  0.398
#  *    JHNHA :      1.110
#  *    JCC :      0.172
#  *    SAXS :      0.016
#  *    PRE_24 :      0.107
#  *    PRE_62 :      0.108
#  *    PRE_87 :      0.129
#  *    PRE_103 :      0.150
# Reweight Data = PRE_62
# 0.20
# PRE_62 Theta: 0.20199497487437185 Kish: 17.455184 RMSD initail: 0.1026 RMSD final: 0.0685
# Initial RMSE reweight data
#  * Total :      0.103
#  *    PRE_62 :      0.103
# Initial RMSE validation data
#  * Total :      0.842
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.068
#  *    PRE_62 :      0.068
# Final RMSE validation data
#  * Total :      0.825
#  *    CA :      0.497
#  *    CB :      1.034
#  *     C :      0.313
#  *     H :      0.140
#  *     N :      1.448
#  *    RDC :      1.761
#  *    RDC Q_scaled:  0.387
#  *    JHNHA :      1.115
#  *    JCC :      0.170
#  *    SAXS :      0.013
#  *    PRE_24 :      0.114
#  *    PRE_42 :      0.115
#  *    PRE_87 :      0.122
#  *    PRE_103 :      0.150
# Reweight Data = PRE_87
# 0.20
# PRE_87 Theta: 0.20199497487437185 Kish: 10.139536 RMSD initail: 0.1566 RMSD final: 0.0603
# Initial RMSE reweight data
#  * Total :      0.157
#  *    PRE_87 :      0.157
# Initial RMSE validation data
#  * Total :      0.839
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.060
#  *    PRE_87 :      0.060
# Final RMSE validation data
#  * Total :      0.823
#  *    CA :      0.524
#  *    CB :      0.981
#  *     C :      0.300
#  *     H :      0.145
#  *     N :      1.454
#  *    RDC :      1.769
#  *    RDC Q_scaled:  0.386
#  *    JHNHA :      1.158
#  *    JCC :      0.145
#  *    SAXS :      0.013
#  *    PRE_24 :      0.109
#  *    PRE_42 :      0.105
#  *    PRE_62 :      0.111
#  *    PRE_103 :      0.149
# Reweight Data = PRE_103
# 0.40
# PRE_103 Theta: 0.4029899497487437 Kish: 19.576512 RMSD initail: 0.1495 RMSD final: 0.0935
# Initial RMSE reweight data
#  * Total :      0.150
#  *    PRE_103 :      0.150
# Initial RMSE validation data
#  * Total :      0.841
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    SAXS :      0.014
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
# Final RMSE reweight data
#  * Total :      0.094
#  *    PRE_103 :      0.094
# Final RMSE validation data
#  * Total :      0.873
#  *    CA :      0.540
#  *    CB :      1.010
#  *     C :      0.315
#  *     H :      0.142
#  *     N :      1.499
#  *    RDC :      1.977
#  *    RDC Q_scaled:  0.430
#  *    JHNHA :      1.110
#  *    JCC :      0.174
#  *    SAXS :      0.016
#  *    PRE_24 :      0.105
#  *    PRE_42 :      0.103
#  *    PRE_62 :      0.099
#  *    PRE_87 :      0.132
# Reweight Data = SAXS
# 0.10
# SAXS Theta: 0.10149748743718592 Kish: 91.597058 RMSD initail: 0.0142 RMSD final: 0.0120
# Initial RMSE reweight data
#  * Total :      0.014
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.827
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.012
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      0.819
#  *    CA :      0.505
#  *    CB :      1.037
#  *     C :      0.309
#  *     H :      0.136
#  *     N :      1.447
#  *    RDC :      1.805
#  *    RDC Q_scaled:  0.397
#  *    JHNHA :      1.114
#  *    JCC :      0.180
#  *    PRE_24 :      0.103
#  *    PRE_42 :      0.109
#  *    PRE_62 :      0.100
#  *    PRE_87 :      0.150
#  *    PRE_103 :      0.150

# %% [markdown]
# DOING REWEIGHTING ON A RANGE OF PARAMETER VALUES AFTER COMBINING ALL DATA

# %%
combined_reweighting_keys = [reweighting_keys]
print('Reweighting keys: {}'.format(combined_reweighting_keys))

To_Scan = combined_reweighting_keys
thetas = np.linspace(0.01, 20, 20)
ref_theta = thetas[-1]
RMSE_dict_combined = {}
KishScan_combined = {}
for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    KishScan_combined[CS] = {}
    CS_dir = join(combined_dir, CS)
    if not os.path.exists(CS_dir):
        os.makedirs(CS_dir)
    print('Reweight Data = {}'.format(CS))
    RMSE_dict_combined[CS] = {}
    combined_key_string = CS

    ### debugging variables
    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}

    ####### B) The reweighting procedure

    obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(
        Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)
    # THETA CYCLE
    theta_list = []
    kish_list = []
    rmsd_f_list = []
    for theta_m in np.flip(thetas):

        s = '{:.2f}'.format(theta_m)
        print(s)
        sigma_reg = theta_m * err_r
        sigma_md = sigma_md_r
        RMSE_dict_combined[CS][s] = {}

        # iv) Print dimensions
        nobs_r = len(obs_exp_r)
        nobs_v = len(obs_exp_v)
        # Print_Number_of_Data(nframes, nobs_r, nobs_v, data_r_type, data_v_type)

        # v) perform minimization
        # OBS: res.X = lagrange multiplier
        weight_bias = np.ones(nframes)
        if 'RDC' in Reweight_Data:
            initial_weights = weight_bias
            initial_weights /= np.sum(initial_weights)
            initial_obs_r = np.dot(traj_r, initial_weights)
            initial_obs_r
            exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
            calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
            qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
            qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

            if (qf_neg < qf_pos):
                c = -c_neg
            else:
                c = c_pos

            RDC_rows = np.where(data_r_type['RDC'] == 1)
            traj_r[RDC_rows] = traj_r[RDC_rows] * c

        res = sp.optimize.minimize(func_sigma_reg_sigma_md,
                                    args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                    x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
        initial_weights = Normalize_Weights(weight_bias)
        initial_obs_r = np.dot(traj_r, initial_weights)
        # if res.success: print("\nMinimization worked: {}\n".format(res.success))
        # else: raise ValueError('Minimization with {}, theta = {} as reweighting data did not worked!'.format(CS, s))
        final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
        # e) final average observables for reweighting and validation
        final_obs_r = np.dot(traj_r, final_weights)

        # g) calculating Kish effective size
        Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
        Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)

        Kish_ratio = (Ks_a / Ks_b) * 100
        RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
        RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))
        # print(CS,"Theta:",theta_m,"Kish: %9.6lf" % (Kish_ratio),"RMSD initail: %0.4f"%RMSE_initial,"RMSD final: %0.4f"%RMSE_reweight)
        theta_list.append(theta_m)
        kish_list.append(Kish_ratio)
        rmsd_f_list.append(RMSE_reweight)
        RMSE_r_i = {}
        RMSE_r_f = {}
        RMSE_r_i['Tot'] = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))

        for t in data_r_type:
            RMSE_r_i[t] = np.sqrt(
                np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                    obs_exp_r * data_r_type['RDC'])
                RMSE_r_i['RDC'] = qf

        RMSE_r_f['Tot'] = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))
        for t in data_r_type:
            RMSE_r_f[t] = np.sqrt(np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                    obs_exp_r * data_r_type['RDC'])
                RMSE_r_f['RDC'] = qf

        RMSE_dict_combined[CS][s]['Kish'] = Kish_ratio
        RMSE_dict_combined[CS][s]['r_i'] = RMSE_r_i
        RMSE_dict_combined[CS][s]['r_f'] = RMSE_r_f
    KishScan_combined[CS]['kish'] = np.column_stack((theta_list, kish_list))
    KishScan_combined[CS]['rmsd'] = np.column_stack((theta_list, rmsd_f_list))
# Out:
# Reweighting keys: [['CA', 'CB', 'H', 'C', 'N', 'RDC', 'JHNHA', 'JCC', 'PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103', 'SAXS']]
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 20.00
# 18.95
# 17.90
# 16.84
# 15.79
# 14.74
# 13.69
# 12.64
# 11.58
# 10.53
# 9.48
# 8.43
# 7.37
# 6.32
# 5.27
# 4.22
# 3.17
# 2.11
# 1.06
# 0.01

# %% [markdown]
# FINDING THE OPTIMAL PARAMETER FOR COMBINED REWEIGHTING

# %%
kish_min = 10
theta_dict_combined = {}
Kish_ratio_vals = []
for key in KishScan_combined:
    k = KishScan_combined[key]['kish']
    b = (np.where(k[:, 1] >= kish_min))[0]
    idx = b[-1]
    idy = b[-2]
    theta_m = k[idx][0]
    Kish_ratio_vals.append(theta_m)
    if (theta_m == 0):
        theta_m = k[idy][0]
    theta_dict_combined[key] = {}
    theta_dict_combined[key] = (theta_m)
    print(key, theta_m)
# Out:
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS 3.1663157894736838

# %%
def print_comb_results():
    print(CS, "Theta:", theta_m, "Kish: %9.6lf" % (Kish_ratio), "RMSD initail: %0.4f" % RMSE_initial,
          "RMSD final: %0.4f" % RMSE_reweight)

    # Iniitial RMSE and Sigma
    print("Initial RMSE reweight data ")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print(
            "     %6.3lf" % np.sqrt(np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))

        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                               obs_exp_r * data_r_type['RDC'])
            # print(" *    RDC scaled RMSD:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE reweight data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdcs_scale_f, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])
            # print(" *    RDC RMSE_scale:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)

# %% [markdown]
# FUNCTION TO PLOT THE FITTING DATA

# %%
PREs = ['PRE_24', 'PRE_42', 'PRE_62', 'PRE_87', 'PRE_103']
from matplotlib.ticker import StrMethodFormatter

def plot_fitting_data(weights):
    for t in Reweight_Data:
        if t != 'Rg':
            print(t)
            resid = []
            exp = []
            for i, id in enumerate(compare_dict_r[t]):
                resid.append(float(id))
            initial = np.trim_zeros(initial_obs_r * data_r_type[t])
            reweight = np.trim_zeros(final_obs_r * data_r_type[t])
            exp = np.trim_zeros(obs_exp_r * data_r_type[t])
            rmsd_i = (sum(np.square(initial - exp)) / len(exp)) ** 0.5
            rmsd_f = (sum(np.square(reweight - exp)) / len(exp)) ** 0.5
            print("RMSD_initial:%6.3lf" % rmsd_i, "RMSD_final:%6.3lf" % rmsd_f)
    
            if t == 'RDC':
                qi_initial, rms_initial, qf_initial, rms_f_initial, rdc_scale_i_initial, c = scale_rdc_Q(exp, initial)
                qi_reweight, rms_i_reweight, qf_reweight, rms_f_reweight, rdc_scale_i_reweight, c = scale_rdc_Q(exp,
                                                                                                                reweight)
                print("RMSD initial scale:%6.3lf" % rms_f_initial, "RMSD final scale:%6.3lf" % rms_f_reweight)
                print("Q initial scale:%6.3lf" % qf_initial, "Q final scale:%6.3lf" % qf_reweight)
                plt.plot(np.asarray(resid), initial, color='red', label="Unbiased")
                plt.plot(np.asarray(resid), reweight, color='darkred', label="Reweighted", linestyle='dashed')
                plt.plot(np.asarray(resid), exp, color='black', label='Exp')
                plt.ylabel(r'$D_{N-HN}$(Hz)', size=18)
                plt.title('%s' % t, size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.grid()
                plt.xlabel('Residues', size=18)
                plt.legend( loc='upper right', fontsize=12)
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

            elif t == 'SAXS':
                plt.gca().xaxis.set_major_formatter(StrMethodFormatter('{x:,.2f}'))
                plt.plot(np.asarray(resid), initial, color='red', label="Unbiased")
                plt.plot(np.asarray(resid), reweight, color='darkred', linestyle='dashed' ,label="Reweighted")
                plt.plot(np.asarray(resid), exp, color='black', label='Exp')
                plt.ylabel('Peak Intensity', size=18)
                plt.title('%s' % t, size='20')
                plt.xticks(size='12')
                plt.yticks(size='12')
                plt.grid()
                plt.xlabel('Scattering angle (q)', size=18, labelpad=7)
                plt.legend(loc='upper right', fontsize=12)
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()
            elif t == 'CA':
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$CS_{calc}$- $CS_{exp}$|', size=20)
                plt.title(r"C$\alpha$", size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.grid()
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

            elif t == 'CB':
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$CS_{calc}$- $CS_{exp}$|', size=20)
                plt.title(r"C$\beta$", size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.grid()
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

            elif t == 'HA':
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$CS_{calc}$- $CS_{exp}$|', size=20)
                plt.title(r"H$\alpha$", size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.grid()
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

            elif t == "JHNHA":
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$^3J_{calc}$- $^3J_{exp}$|', size=20)
                plt.title(r"$^3JHNH\alpha$", size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.grid()
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.png'%(outdir,t), bbox_inches='tight')
                plt.show()

            elif t in PREs:

                plt.plot(np.asarray(resid), initial, color='red', label='Unbiased')
                plt.plot(np.asarray(resid), reweight, color='darkred', linestyle='dashed', label='Reweighted')
                plt.plot(np.asarray(resid), exp, color='black', label='Experiment')
                plt.ylabel('Peak Intensity', size=18)
                plt.title('%s' % t, size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.grid()
                plt.xlabel('Residue', size=18)
                plt.legend(bbox_to_anchor=(1, 1.0), loc='upper left', fontsize=12)
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf'%(outdir,t), bbox_inches='tight')
                plt.show()



            else:
                plt.plot(np.asarray(resid), np.absolute(initial - exp), color='red',
                         label="RMSD_initial:%6.3lf" % rmsd_i)
                plt.plot(np.asarray(resid), np.absolute(reweight - exp), color='darkred', linestyle='dashed',
                         label="RMSD_final:%6.3lf" % rmsd_f)
                plt.fill_between(np.asarray(resid), np.absolute(reweight - exp), np.absolute(initial - exp),
                                 color='tomato', alpha=0.3)
                plt.ylabel(r'|$CS_{calc}$- $CS_{exp}$|', size=20)
                plt.title('%s' % t, size='20')
                plt.xticks(fontsize=16)
                plt.yticks(fontsize=16)
                plt.xticks(size='18')
                plt.yticks(size='18')
                plt.xlabel('Residue', size=18)
                plt.legend(loc='upper right')
                plt.grid()
                plt.tight_layout()
                plt.savefig('%s/%s.reweight.dev.pdf' % (outdir, t), bbox_inches='tight')
                plt.show()

# %% [markdown]
# REWEIGHTING WITH ALL THE DATA AND PLOTTING THE FIT TO EXPERIMENT

# %%
To_Scan=combined_reweighting_keys


CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(To_Scan[0], true_exp_labels)
obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)


s = '{:.2f}'.format(theta_m)

sigma_reg=theta_m*err_r
sigma_md=sigma_md_r
        

nobs_r = len(obs_exp_r)
nobs_v = len(obs_exp_v)
weight_bias=np.ones(nframes)
if 'RDC' in Reweight_Data:    
       initial_weights=weight_bias
       initial_weights/=np.sum(initial_weights)
       initial_obs_r=np.dot(traj_r,initial_weights)
       initial_obs_r
       exp_rdc=np.trim_zeros(obs_exp_r*data_r_type['RDC'])
       calc_rdc=np.trim_zeros(initial_obs_r*data_r_type['RDC'])
       qi_pos,rms_i_pos,qf_pos,rms_f_pos,rdc_scale_pos,c_pos=scale_rdc_Q(exp_rdc,calc_rdc)
       #print(qi_pos,rms_i_pos,qf_pos,rms_f_pos,rdc_scale_pos,c_pos)    
       qi_neg,rms_i_neg,qf_neg,rms_f_neg,rdc_scale_neg,c_neg=scale_rdc_Q(-exp_rdc,calc_rdc)
       #print(qi_neg,rms_i_neg,qf_neg,rms_f_neg,rdc_scale_neg,c_neg)

       if(qf_neg<qf_pos):
        c=-c_neg
       else: 
        c=c_pos
    
       RDC_rows=np.where(data_r_type['RDC']==1)
       traj_r[RDC_rows]=traj_r[RDC_rows]*c


res = sp.optimize.minimize(func_sigma_reg_sigma_md, args = (traj_r, obs_exp_r, weight_bias, sigma_reg,sigma_md), x0 =  np.zeros((nobs_r,)), method='L-BFGS-B',jac=True)
initial_weights = Normalize_Weights(weight_bias)
initial_obs_r=np.dot(traj_r,initial_weights)
final_weights = Normalize_Weights(weight_bias-np.dot(res.x,traj_r))
final_obs_r=np.dot(traj_r,final_weights)
Ks_b = np.average(initial_weights)**2/np.average(initial_weights**2)
Ks_a = np.average(final_weights)**2/np.average(final_weights**2)
        
Kish_ratio = (Ks_a/Ks_b)*100
RMSE_initial=np.sqrt(np.mean((initial_obs_r-obs_exp_r)**2))
RMSE_reweight=np.sqrt(np.mean((final_obs_r-obs_exp_r)**2))

plot_fitting_data(final_weights)
print_comb_results()

np.savetxt('%s/weights_final.dat' % (CS_dir), final_weights, fmt=" %6.12lf")
# print final weights to file

f = open("%s/weights_final.a.dat" % CS_dir, "w")
for w in final_weights:
       f.write("%e\n" % w)
f.close()
# Out:
# CA
# RMSD_initial: 0.506 RMSD_final: 0.475
# CB
# RMSD_initial: 1.043 RMSD_final: 0.982
# H
# RMSD_initial: 0.136 RMSD_final: 0.131
# C
# RMSD_initial: 0.314 RMSD_final: 0.283
# N
# RMSD_initial: 1.457 RMSD_final: 1.327
# RDC
# RMSD_initial: 1.835 RMSD_final: 1.304
# RMSD initial scale: 1.835 RMSD final scale: 1.270
# Q initial scale: 0.403 Q final scale: 0.279
# JHNHA
# RMSD_initial: 1.111 RMSD_final: 1.075
# JCC
# RMSD_initial: 0.182 RMSD_final: 0.099
# PRE_24
# RMSD_initial: 0.106 RMSD_final: 0.090
# PRE_42
# RMSD_initial: 0.107 RMSD_final: 0.076
# PRE_62
# RMSD_initial: 0.103 RMSD_final: 0.084
# PRE_87
# RMSD_initial: 0.157 RMSD_final: 0.086
# PRE_103
# RMSD_initial: 0.150 RMSD_final: 0.131
# SAXS
# RMSD_initial: 0.014 RMSD_final: 0.012
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 13.349480 RMSD initail: 0.8149 RMSD final: 0.6897
# Initial RMSE reweight data
#  * Total :      0.815
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Final RMSE reweight data
#  * Total :      0.690
#  *    CA :      0.475
#  *    CB :      0.982
#  *     H :      0.131
#  *     C :      0.283
#  *     N :      1.327
#  *    RDC :      1.304
#  *    RDC Q_scaled:  0.279
#  *    JHNHA :      1.075
#  *    JCC :      0.099
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.086
#  *    PRE_103 :      0.131
#  *    SAXS :      0.012

# %% [markdown]
# MAKING THE KEYS FOR CROSS-VALIDATION REWEIGHTING BY LEAVING ONE DATATYPE AT A TIME

# %%
new_rwt_keys = []
for i in range(len(reweighting_keys)):
    new_list = reweighting_keys.copy()
    del new_list[i]
    new_rwt_keys.append(new_list)

# %% [markdown]
# DOING A SCAN TO FIND OPTIMAL PARAMETERS FOR CROSS-VALIDATION

# %%
To_Scan = new_rwt_keys
thetas = np.linspace(0.01, 20, 20)
ref_theta = thetas[-1]
RMSE_leave_one_dict = {}
KishScan_leave_one_out = {}
for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    KishScan_leave_one_out[CS] = {}
    print('Reweight Data = {}'.format(CS))
    RMSE_leave_one_dict[CS] = {}

    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}
    compare_dict_v = {key: {} for key in compdata.keys()}

    ####### B) The reweighting procedure

    obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)
    obs_exp_v, traj_v, err_v, sigma_md_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays_with_sigma(Validation_Data, expdata, compdata, theta_0, sd, compare_dict_v)

    # THETA CYCLE
    theta_list = []
    kish_list = []
    rmsd_f_list = []
    for theta_m in np.flip(thetas):

        s = '{:.2f}'.format(theta_m)
        sigma_reg = theta_m * err_r
        sigma_md = sigma_md_r
        RMSE_leave_one_dict[CS][s] = {}

        # iv) Print dimensions
        nobs_r = len(obs_exp_r)
        nobs_v = len(obs_exp_v)
        # Print_Number_of_Data(nframes, nobs_r, nobs_v, data_r_type, data_v_type)

        # v) perform minimization
        # OBS: res.X = lagrange multiplier
        weight_bias = np.ones(nframes)

        if 'RDC' in Reweight_Data:
            initial_weights = weight_bias
            initial_weights /= np.sum(initial_weights)
            initial_obs_r = np.dot(traj_r, initial_weights)
            initial_obs_r
            exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
            calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
            qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
            qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

            if (qf_neg < qf_pos):
                c = -c_neg
            else:
                c = c_pos

            RDC_rows = np.where(data_r_type['RDC'] == 1)
            traj_r[RDC_rows] = traj_r[RDC_rows] * c

        if 'RDC' in Validation_Data:
            initial_weights = weight_bias
            initial_weights /= np.sum(initial_weights)
            initial_obs_v = np.dot(traj_v, initial_weights)
            exp_rdc = np.trim_zeros(obs_exp_v * data_v_type['RDC'])
            calc_rdc = np.trim_zeros(initial_obs_v * data_v_type['RDC'])
            qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
            qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

            if (qf_neg < qf_pos):
                c = -c_neg
            else:
                c = c_pos

            RDC_rows = np.where(data_v_type['RDC'] == 1)
            traj_v[RDC_rows] = traj_v[RDC_rows] * c

        res = sp.optimize.minimize(func_sigma_reg_sigma_md,
                                    args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                    x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
        initial_weights = Normalize_Weights(weight_bias)
        initial_obs_r = np.dot(traj_r, initial_weights)
        initial_obs_v = np.dot(traj_v, initial_weights)

        final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
        final_obs_r = np.dot(traj_r, final_weights)
        final_obs_v = np.dot(traj_v, final_weights)
        # g) calculating Kish effective size
        Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
        Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)

        Kish_ratio = (Ks_a / Ks_b) * 100
        RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
        RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

        theta_list.append(theta_m)
        kish_list.append(Kish_ratio)
        rmsd_f_list.append(RMSE_reweight)
        RMSE_r_i = {}
        RMSE_v_i = {}
        RMSE_r_f = {}
        RMSE_v_f = {}
        RMSE_r_i['Tot'] = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))

        for t in data_r_type:
            RMSE_r_i[t] = np.sqrt(
                np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                    obs_exp_r * data_r_type['RDC'])
                RMSE_r_i['RDC'] = qf

        RMSE_v_i['Tot'] = np.sqrt(
            np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
        for t in data_v_type:
            RMSE_v_i[t] = np.sqrt(
                np.sum((initial_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_v * data_v_type['RDC'],
                                                                    obs_exp_v * data_v_type['RDC'])
                RMSE_v_i['RDC'] = qf

        RMSE_r_f['Tot'] = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

        for t in data_r_type:
            RMSE_r_f[t] = np.sqrt(np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                    obs_exp_r * data_r_type['RDC'])
                RMSE_r_f['RDC'] = qf

        for t in data_v_type:
            RMSE_v_f[t] = np.sqrt(np.sum((final_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t]))
            if str(t) == 'RDC':
                qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(final_obs_v * data_v_type['RDC'],
                                                                    obs_exp_v * data_v_type['RDC'])
                RMSE_v_f['RDC'] = qf

        RMSE_leave_one_dict[CS][s]['Kish'] = Kish_ratio
        RMSE_leave_one_dict[CS][s]['r_i'] = RMSE_r_i
        RMSE_leave_one_dict[CS][s]['r_f'] = RMSE_r_f
        RMSE_leave_one_dict[CS][s]['v_i'] = RMSE_v_i
        RMSE_leave_one_dict[CS][s]['v_f'] = RMSE_v_f

    KishScan_leave_one_out[CS]['kish'] = np.column_stack((theta_list, kish_list))
    KishScan_leave_one_out[CS]['rmsd'] = np.column_stack((theta_list, rmsd_f_list))
# Out:
# Reweight Data = CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_62-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_87-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_103-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-SAXS
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103

# %% [markdown]
# FINDING OPTIMAL PARAMETER VALUE FOR CROSS-VALIDATION REWEIGHTING

# %%
kish_min = 10
theta_dict_leave_one = {}
Kish_ratio_vals = []
for key in KishScan_leave_one_out:
    k = KishScan_leave_one_out[key]['kish']
    b = (np.where(k[:, 1] >= kish_min))[0]
    idx = b[-1]
    idy = b[-2]
    theta_m = k[idx][0]
    Kish_ratio_vals.append(theta_m)
    if (theta_m == 0):
        theta_m = k[idy][0]
    theta_dict_leave_one[key] = {}
    theta_dict_leave_one[key] = (theta_m)

# %% [markdown]
# CROSS-VALIDATION REWEIGHTING WITH OPTIMAL PARAMETERS

# %%
 To_Scan = new_rwt_keys

for CS in To_Scan:
    CS, Reweight_Data, Validation_Data = Separate_Validation_Reweighting_Data(CS, true_exp_labels)
    print('Reweight Data = {}'.format(CS))
    CS_dir = join(leave_dir, CS)
    if not os.path.exists(CS_dir):
        os.makedirs(CS_dir)

    compare = []
    compare_dict_r = {key: {} for key in compdata.keys()}
    compare_dict_v = {key: {} for key in compdata.keys()}

    obs_exp_r, traj_r, err_r, sigma_md_r, data_r_t, data_r_type, compare_dict_r = Process_Data_Into_Arrays_with_sigma(
        Reweight_Data, expdata, compdata, theta_dict, sd, compare_dict_r)
    obs_exp_v, traj_v, err_v, sigma_md_v, data_v_t, data_v_type, compare_dict_v = Process_Data_Into_Arrays_with_sigma(
        Validation_Data, expdata, compdata, theta_0, sd, compare_dict_v)

    theta_m = theta_dict_leave_one[CS]
    s = '{:.2f}'.format(theta_m)
    print(s)
    sigma_reg = theta_m * err_r
    sigma_md = sigma_md_r

    # iv) Print dimensions
    nobs_r = len(obs_exp_r)
    nobs_v = len(obs_exp_v)

    # v) perform minimization
    # OBS: res.X = lagrange multiplier
    weight_bias = np.ones(nframes)
    if 'RDC' in Reweight_Data:
        intial_weights = weight_bias
        initial_weights /= np.sum(initial_weights)
        initial_obs_r = np.dot(traj_r, initial_weights)
        initial_obs_r
        exp_rdc = np.trim_zeros(obs_exp_r * data_r_type['RDC'])
        calc_rdc = np.trim_zeros(initial_obs_r * data_r_type['RDC'])
        qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
        qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

        if (qf_neg < qf_pos):
            c = -c_neg
        else:
            c = c_pos
        RDC_rows = np.where(data_r_type['RDC'] == 1)
        traj_r[RDC_rows] = traj_r[RDC_rows] * c

    if 'RDC' in Validation_Data:
        intial_weights = weight_bias
        initial_weights /= np.sum(initial_weights)
        initial_obs_v = np.dot(traj_v, initial_weights)
        initial_obs_v
        exp_rdc = np.trim_zeros(obs_exp_v * data_v_type['RDC'])
        calc_rdc = np.trim_zeros(initial_obs_v * data_v_type['RDC'])
        qi_pos, rms_i_pos, qf_pos, rms_f_pos, rdc_scale_pos, c_pos = scale_rdc_Q(exp_rdc, calc_rdc)
        qi_neg, rms_i_neg, qf_neg, rms_f_neg, rdc_scale_neg, c_neg = scale_rdc_Q(-exp_rdc, calc_rdc)

        if (qf_neg < qf_pos):
            c = -c_neg
        else:
            c = c_pos
        RDC_rows = np.where(data_v_type['RDC'] == 1)
        traj_v[RDC_rows] = traj_v[RDC_rows] * c

    res = sp.optimize.minimize(func_sigma_reg_sigma_md, args=(traj_r, obs_exp_r, weight_bias, sigma_reg, sigma_md),
                                x0=np.zeros((nobs_r,)), method='L-BFGS-B', jac=True)
    initial_weights = Normalize_Weights(weight_bias)
    initial_obs_r = np.dot(traj_r, initial_weights)
    initial_obs_v = np.dot(traj_v, initial_weights)
    # if res.success: print("\nMinimization worked: {}\n".format(res.success))
    # else: raise ValueError('Minimization with {}, theta = {} as reweighting data did not worked!'.format(CS, s))
    final_weights = Normalize_Weights(weight_bias - np.dot(res.x, traj_r))
    # e) final average observables for reweighting and validation
    final_obs_r = np.dot(traj_r, final_weights)
    final_obs_v = np.dot(traj_v, final_weights)
    # g) calculating Kish effective size
    Ks_b = np.average(initial_weights) ** 2 / np.average(initial_weights ** 2)
    Ks_a = np.average(final_weights) ** 2 / np.average(final_weights ** 2)
    # print("Initial Kish size : %9.6lf %d" % (Ks_b, Ks_b*nframes))
    # print("Reweighted Kish size : %9.6lf %d" % (Ks_a, Ks_a*nframes))
    Kish_ratio = (Ks_a / Ks_b) * 100
    RMSE_initial = np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2))
    RMSE_reweight = np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2))

    #     plot_fitting_data(final_weights)

    print(CS, "Theta:", theta_m, "Kish: %9.6lf" % (Kish_ratio), "RMSD initail: %0.4f" % RMSE_initial,
            "RMSD final: %0.4f" % RMSE_reweight)

    print("Initial RMSE reweight data ")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((initial_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))

        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])
            # print(" *    RDC scaled RMSD:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Initial RMSE validation data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((initial_obs_v - obs_exp_v) ** 2)))

    for t in data_v_type:
        print(" *    %2s :" % t, end='')
        # (initial_obs_v-obs_exp_v)**2*data_v_type[t])
        print("     %6.3lf" % np.sqrt(
            np.sum((initial_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_i, c = scale_rdc_Q(initial_obs_v * data_v_type['RDC'],
                                                                obs_exp_v * data_v_type['RDC'])
            # print(" *    RDC scaled RMSD:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC scaled Q:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE reweight data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_r - obs_exp_r) ** 2)))

    for t in data_r_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((final_obs_r - obs_exp_r) ** 2 * data_r_type[t]) / np.sum(data_r_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdcs_scale_f, c = scale_rdc_Q(final_obs_r * data_r_type['RDC'],
                                                                obs_exp_r * data_r_type['RDC'])
            # print(" *    RDC RMSE_scale:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)

    print("Final RMSE validation data")
    print(" * Total :     %6.3lf" % np.sqrt(np.mean((final_obs_v - obs_exp_v) ** 2)))

    for t in data_v_type:
        print(" *    %2s :" % t, end='')
        print("     %6.3lf" % np.sqrt(
            np.sum((final_obs_v - obs_exp_v) ** 2 * data_v_type[t]) / np.sum(data_v_type[t])))
        if str(t) == 'RDC':
            qi, rms_i, qf, rms_f, rdc_scale_f, c = scale_rdc_Q(final_obs_v * data_v_type['RDC'],
                                                                obs_exp_v * data_v_type['RDC'])
            # print(" *    RDC RMSE_scale:", end = '')
            # print(" %6.3lf" % rms_f)
            print(" *    RDC Q_scaled:", end='')
            print(" %6.3lf" % qf)
    np.savetxt('%s/weights_final.dat' % (CS_dir), final_weights, fmt=" %6.12lf")
    # print final weights to file

    f = open("%s/weights_final.a.dat" % CS_dir, "w")
    for w in final_weights:
        f.write("%e\n" % w)
    f.close()
# Out:
# Reweight Data = CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 14.081586 RMSD initail: 0.8422 RMSD final: 0.7176
# Initial RMSE reweight data
#  * Total :      0.842
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.506
#  *    CA :      0.506
# Final RMSE reweight data
#  * Total :      0.718
#  *    CB :      0.973
#  *     H :      0.133
#  *     C :      0.279
#  *     N :      1.346
#  *    RDC :      1.328
#  *    RDC Q_scaled:  0.282
#  *    JHNHA :      1.097
#  *    JCC :      0.098
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.085
#  *    PRE_103 :      0.130
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      0.498
#  *    CA :      0.498
# Reweight Data = CA-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 13.864474 RMSD initail: 0.7911 RMSD final: 0.6549
# Initial RMSE reweight data
#  * Total :      0.791
#  *    CA :      0.506
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      1.043
#  *    CB :      1.043
# Final RMSE reweight data
#  * Total :      0.655
#  *    CA :      0.469
#  *     H :      0.129
#  *     C :      0.286
#  *     N :      1.325
#  *    RDC :      1.301
#  *    RDC Q_scaled:  0.280
#  *    JHNHA :      1.064
#  *    JCC :      0.101
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.086
#  *    PRE_103 :      0.131
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      0.997
#  *    CB :      0.997
# Reweight Data = CA-CB-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 13.926842 RMSD initail: 0.8577 RMSD final: 0.7321
# Initial RMSE reweight data
#  * Total :      0.858
#  *    CA :      0.506
#  *    CB :      1.043
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.136
#  *     H :      0.136
# Final RMSE reweight data
#  * Total :      0.732
#  *    CA :      0.482
#  *    CB :      0.977
#  *     C :      0.282
#  *     N :      1.348
#  *    RDC :      1.317
#  *    RDC Q_scaled:  0.281
#  *    JHNHA :      1.081
#  *    JCC :      0.098
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.083
#  *    PRE_87 :      0.085
#  *    PRE_103 :      0.130
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      0.136
#  *     H :      0.136
# Reweight Data = CA-CB-H-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 13.279454 RMSD initail: 0.8519 RMSD final: 0.7189
# Initial RMSE reweight data
#  * Total :      0.852
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.314
#  *     C :      0.314
# Final RMSE reweight data
#  * Total :      0.719
#  *    CA :      0.469
#  *    CB :      0.988
#  *     H :      0.130
#  *     N :      1.322
#  *    RDC :      1.305
#  *    RDC Q_scaled:  0.281
#  *    JHNHA :      1.067
#  *    JCC :      0.100
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.086
#  *    PRE_103 :      0.130
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      0.297
#  *     C :      0.297
# Reweight Data = CA-CB-H-C-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 14.238696 RMSD initail: 0.7087 RMSD final: 0.5800
# Initial RMSE reweight data
#  * Total :      0.709
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      1.457
#  *     N :      1.457
# Final RMSE reweight data
#  * Total :      0.580
#  *    CA :      0.481
#  *    CB :      0.981
#  *     H :      0.133
#  *     C :      0.282
#  *    RDC :      1.317
#  *    RDC Q_scaled:  0.281
#  *    JHNHA :      1.073
#  *    JCC :      0.099
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.083
#  *    PRE_87 :      0.085
#  *    PRE_103 :      0.130
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      1.386
#  *     N :      1.386
# Reweight Data = CA-CB-H-C-N-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 15.677785 RMSD initail: 0.6595 RMSD final: 0.6132
# Initial RMSE reweight data
#  * Total :      0.660
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      1.835
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
# Final RMSE reweight data
#  * Total :      0.613
#  *    CA :      0.482
#  *    CB :      0.981
#  *     H :      0.132
#  *     C :      0.284
#  *     N :      1.339
#  *    JHNHA :      1.077
#  *    JCC :      0.099
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.083
#  *    PRE_87 :      0.085
#  *    PRE_103 :      0.130
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      1.636
#  *    RDC :      1.636
#  *    RDC Q_scaled:  0.354
# Reweight Data = CA-CB-H-C-N-RDC-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 13.968945 RMSD initail: 0.7983 RMSD final: 0.6663
# Initial RMSE reweight data
#  * Total :      0.798
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      1.111
#  *    JHNHA :      1.111
# Final RMSE reweight data
#  * Total :      0.666
#  *    CA :      0.483
#  *    CB :      0.977
#  *     H :      0.131
#  *     C :      0.281
#  *     N :      1.326
#  *    RDC :      1.308
#  *    RDC Q_scaled:  0.279
#  *    JCC :      0.097
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.085
#  *    PRE_103 :      0.131
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      1.142
#  *    JHNHA :      1.142
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 18.596625 RMSD initail: 0.8358 RMSD final: 0.7102
# Initial RMSE reweight data
#  * Total :      0.836
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.182
#  *    JCC :      0.182
# Final RMSE reweight data
#  * Total :      0.710
#  *    CA :      0.472
#  *    CB :      0.995
#  *     H :      0.130
#  *     C :      0.289
#  *     N :      1.334
#  *    RDC :      1.309
#  *    RDC Q_scaled:  0.281
#  *    JHNHA :      1.052
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.077
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.087
#  *    PRE_103 :      0.131
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      0.144
#  *    JCC :      0.144
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_42-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_42-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 14.918790 RMSD initail: 0.8430 RMSD final: 0.7140
# Initial RMSE reweight data
#  * Total :      0.843
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.106
#  *    PRE_24 :      0.106
# Final RMSE reweight data
#  * Total :      0.714
#  *    CA :      0.475
#  *    CB :      0.984
#  *     H :      0.131
#  *     C :      0.284
#  *     N :      1.334
#  *    RDC :      1.298
#  *    RDC Q_scaled:  0.278
#  *    JHNHA :      1.074
#  *    JCC :      0.099
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.086
#  *    PRE_103 :      0.131
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      0.102
#  *    PRE_24 :      0.102
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_62-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_62-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 16.651326 RMSD initail: 0.8423 RMSD final: 0.7077
# Initial RMSE reweight data
#  * Total :      0.842
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.107
#  *    PRE_42 :      0.107
# Final RMSE reweight data
#  * Total :      0.708
#  *    CA :      0.471
#  *    CB :      0.984
#  *     H :      0.129
#  *     C :      0.283
#  *     N :      1.319
#  *    RDC :      1.284
#  *    RDC Q_scaled:  0.276
#  *    JHNHA :      1.069
#  *    JCC :      0.100
#  *    PRE_24 :      0.088
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.087
#  *    PRE_103 :      0.129
#  *    SAXS :      0.013
# Final RMSE validation data
#  * Total :      0.102
#  *    PRE_42 :      0.102
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_87-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_87-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 16.187628 RMSD initail: 0.8420 RMSD final: 0.7100
# Initial RMSE reweight data
#  * Total :      0.842
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.103
#  *    PRE_62 :      0.103
# Final RMSE reweight data
#  * Total :      0.710
#  *    CA :      0.474
#  *    CB :      0.983
#  *     H :      0.130
#  *     C :      0.284
#  *     N :      1.323
#  *    RDC :      1.293
#  *    RDC Q_scaled:  0.278
#  *    JHNHA :      1.074
#  *    JCC :      0.099
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.077
#  *    PRE_87 :      0.085
#  *    PRE_103 :      0.132
#  *    SAXS :      0.013
# Final RMSE validation data
#  * Total :      0.097
#  *    PRE_62 :      0.097
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_103-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_103-SAXS Theta: 3.1663157894736838 Kish: 16.402184 RMSD initail: 0.8387 RMSD final: 0.7069
# Initial RMSE reweight data
#  * Total :      0.839
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_103 :      0.150
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.157
#  *    PRE_87 :      0.157
# Final RMSE reweight data
#  * Total :      0.707
#  *    CA :      0.466
#  *    CB :      0.993
#  *     H :      0.128
#  *     C :      0.285
#  *     N :      1.318
#  *    RDC :      1.296
#  *    RDC Q_scaled:  0.281
#  *    JHNHA :      1.060
#  *    JCC :      0.104
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.077
#  *    PRE_62 :      0.084
#  *    PRE_103 :      0.133
#  *    SAXS :      0.012
# Final RMSE validation data
#  * Total :      0.107
#  *    PRE_87 :      0.107
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-SAXS
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-SAXS Theta: 3.1663157894736838 Kish: 14.506382 RMSD initail: 0.8408 RMSD final: 0.7113
# Initial RMSE reweight data
#  * Total :      0.841
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    SAXS :      0.014
# Initial RMSE validation data
#  * Total :      0.150
#  *    PRE_103 :      0.150
# Final RMSE reweight data
#  * Total :      0.711
#  *    CA :      0.474
#  *    CB :      0.984
#  *     H :      0.130
#  *     C :      0.283
#  *     N :      1.323
#  *    RDC :      1.305
#  *    RDC Q_scaled:  0.281
#  *    JHNHA :      1.078
#  *    JCC :      0.099
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.086
#  *    SAXS :      0.013
# Final RMSE validation data
#  * Total :      0.143
#  *    PRE_103 :      0.143
# Reweight Data = CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103
# 3.17
# CA-CB-H-C-N-RDC-JHNHA-JCC-PRE_24-PRE_42-PRE_62-PRE_87-PRE_103 Theta: 3.1663157894736838 Kish: 13.285503 RMSD initail: 0.8268 RMSD final: 0.6990
# Initial RMSE reweight data
#  * Total :      0.827
#  *    CA :      0.506
#  *    CB :      1.043
#  *     H :      0.136
#  *     C :      0.314
#  *     N :      1.457
#  *    RDC :      1.835
#  *    RDC scaled Q:  0.403
#  *    JHNHA :      1.111
#  *    JCC :      0.182
#  *    PRE_24 :      0.106
#  *    PRE_42 :      0.107
#  *    PRE_62 :      0.103
#  *    PRE_87 :      0.157
#  *    PRE_103 :      0.150
# Initial RMSE validation data
#  * Total :      0.014
#  *    SAXS :      0.014
# Final RMSE reweight data
#  * Total :      0.699
#  *    CA :      0.474
#  *    CB :      0.982
#  *     H :      0.130
#  *     C :      0.283
#  *     N :      1.325
#  *    RDC :      1.303
#  *    RDC Q_scaled:  0.279
#  *    JHNHA :      1.074
#  *    JCC :      0.099
#  *    PRE_24 :      0.090
#  *    PRE_42 :      0.076
#  *    PRE_62 :      0.084
#  *    PRE_87 :      0.086
#  *    PRE_103 :      0.131
# Final RMSE validation data
#  * Total :      0.013
#  *    SAXS :      0.013

# %% [markdown]
# SAVING ALL THE INFORMATION FROM THE OPTIMIZED REWEIGHTING ROUNDS AS DICTIONARIES TO LOAD FOR MAKING THE ANALYSIS PLOTS

# %%
import pickle

with open('%s/RMSE_single.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(RMSE_dict, fp)

with open('%s/RMSE_leave_one.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(RMSE_leave_one_dict, fp)

with open('%s/RMSE_combined.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(RMSE_dict_combined, fp)

with open('%s/theta_dict.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(theta_dict, fp)

with open('%s/theta_dict_combined.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(theta_dict_combined, fp)

with open('%s/theta_dict_leave_one.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(theta_dict_leave_one, fp)

with open('%s/KishScan_single_data.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(KishScan_one_data, fp)

with open('%s/KishScan_leave_one.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(KishScan_leave_one_out, fp)

with open('%s/KishScan_combined.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(KishScan_combined, fp)

with open('%s/colors.pkl' % dic_dir, 'wb') as fp:
    pickle.dump(colors, fp)
